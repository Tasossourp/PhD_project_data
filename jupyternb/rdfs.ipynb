# %%
import numpy as np
#from matplotlib import rcParams
import matplotlib
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit 
import sys

# %%
matplotlib.rc('font', **{'family':'serif', 'serif':['Computer Modern']})
matplotlib.rc('text', usetex=True)

plt.rc('axes', linewidth=1.25)
plt.rc('xtick.major', size=5, width=1.25)
plt.rc('xtick.minor', size=5, width=1.25)
plt.rc('ytick.major', size=5, width=1.25)
plt.rc('ytick.minor', size=5, width=1.25)
ticklabelsize=11
legendlabelsize=12
axislabelsize=14

# %%
tableau20 = [(31, 119, 180), (174, 199, 232), (255, 127, 14), (255, 187, 120),    
             (44, 160, 44), (152, 223, 138), (214, 39, 40), (255, 152, 150),    
             (148, 103, 189), (197, 176, 213), (140, 86, 75), (196, 156, 148),    
             (227, 119, 194), (247, 182, 210), (127, 127, 127), (199, 199, 199),    
             (188, 189, 34), (219, 219, 141), (23, 190, 207), (158, 218, 229)]

# %%
for i in range(len(tableau20)):    
    r, g, b = tableau20[i]    
    tableau20[i] = (r / 255., g / 255., b / 255.)

# %%
dataniki10=np.loadtxt("/localscratch/asourpis/metadata_MOGON/ff_evalution/niki/10/rdf_ow_hw.xvg")
dataniki50=np.loadtxt("/localscratch/asourpis/metadata_MOGON/ff_evalution/niki/50/rdf_ow_hw.xvg")
dataniki90=np.loadtxt("/localscratch/asourpis/metadata_MOGON/ff_evalution/niki/90/rdf_ow_hw.xvg")

# %%
dataniki10
# Out:
# array([[0.000e+00, 0.000e+00],
#        [2.000e-03, 0.000e+00],
#        [4.000e-03, 0.000e+00],
#        ...,
#        [2.454e+00, 9.990e-01],
#        [2.456e+00, 9.990e-01],
#        [2.458e+00, 9.990e-01]])

# %%
datakows10=np.loadtxt("/localscratch/asourpis/metadata_MOGON/ff_evalution/kows/10/rdf_ow_hw.xvg")
datakows50=np.loadtxt("/localscratch/asourpis/metadata_MOGON/ff_evalution/kows/50/rdf_ow_hw.xvg")
datakows90=np.loadtxt("/localscratch/asourpis/metadata_MOGON/ff_evalution/kows/90/rdf_ow_hw.xvg")

# %%
datagrab10=np.loadtxt("/localscratch/asourpis/metadata_MOGON/ff_evalution/grab/10/rdf_ow_hw.xvg")
datagrab50=np.loadtxt("/localscratch/asourpis/metadata_MOGON/ff_evalution/grab/50/rdf_ow_hw.xvg")
datagrab90=np.loadtxt("/localscratch/asourpis/metadata_MOGON/ff_evalution/grab/90/rdf_ow_hw.xvg")

# %%
datakalu10=np.loadtxt("/localscratch/asourpis/metadata_MOGON/ff_evalution/kalu/10/rdf_ow_hw.xvg")
datakalu50=np.loadtxt("/localscratch/asourpis/metadata_MOGON/ff_evalution/kalu/50/rdf_ow_hw.xvg")
datakalu90=np.loadtxt("/localscratch/asourpis/metadata_MOGON/ff_evalution/kalu/90/rdf_ow_hw.xvg")

# %% [markdown]
# # Cordination number

# %%
dnkalu10_ow_hw=datakalu10[50:125,1]*0.002
dnkalu50_ow_hw=datakalu10[50:125,1]*0.002
dnkalu90_ow_hw=datakalu10[50:125,1]*0.002

nkalu10_ow_hw=sum(dnkalu10_ow_hw)
nkalu10_ow_hw=sum(dnkalu50_ow_hw)
nkalu90_ow_hw=sum(dnkalu90_ow_hw)

[nkalu10_ow_hw,nkalu10_ow_hw,nkalu90_ow_hw]
# Out:
# [0.006206, 0.006206, 0.006206]

# %%
dngrab10_ow_hw=datagrab10[50:125,1]*0.02
dngrab50_ow_hw=datagrab10[50:125,1]*0.02
dngrab90_ow_hw=datagrab10[50:125,1]*0.02

ngrab10_ow_hw=sum(dngrab10_ow_hw)
ngrab10_ow_hw=sum(dngrab50_ow_hw)
ngrab90_ow_hw=sum(dngrab90_ow_hw)

[ngrab10_ow_hw,ngrab10_ow_hw,ngrab90_ow_hw]
# Out:
# [3.990459999999999, 3.990459999999999, 3.990459999999999]

# %%
dnkows10_ow_hw=datakows10[50:125,1]*0.02
dnkows50_ow_hw=datakows10[50:125,1]*0.02
dnkows90_ow_hw=datakows10[50:125,1]*0.02

nkows10_ow_hw=sum(dnkows10_ow_hw)
nkows10_ow_hw=sum(dnkows50_ow_hw)
nkows90_ow_hw=sum(dnkows90_ow_hw)

[nkows10_ow_hw,nkows10_ow_hw,nkows90_ow_hw]
# Out:
# [3.9125199999999984, 3.9125199999999984, 3.9125199999999984]

# %%
dnniki10_ow_hw=dataniki10[50:125,1]*0.02
dnniki50_ow_hw=dataniki10[50:125,1]*0.02
dnniki90_ow_hw=dataniki10[50:125,1]*0.02

nniki10_ow_hw=sum(dnniki10_ow_hw)
nniki10_ow_hw=sum(dnniki50_ow_hw)
nniki90_ow_hw=sum(dnniki90_ow_hw)

[nniki10_ow_hw,nniki10_ow_hw,nniki90_ow_hw]
# Out:
# [3.9905, 3.9905, 3.9905]

# %%
fig, ax = plt.subplots(2, 2, sharex='col', sharey='row')

PLOTRANGE = (0.15,0.7,0,5.0)
x = np.linspace(PLOTRANGE[0],PLOTRANGE[1],1000)

ax[0][0].get_yaxis().set_tick_params(which='both', direction='in')
ax[0][0].get_xaxis().set_tick_params(which='both', direction='in')
ax[0][0].yaxis.set_ticks_position('both')
ax[0][0].xaxis.set_ticks_position('both')
ax[0][0].xaxis.set_tick_params(labelsize=ticklabelsize)
ax[0][0].yaxis.set_tick_params(labelsize=ticklabelsize)

#ax[0][1]=plt.gca()
ax[0][1].get_yaxis().set_tick_params(which='both', direction='in')
ax[0][1].get_xaxis().set_tick_params(which='both', direction='in')
ax[0][1].yaxis.set_ticks_position('both')
ax[0][1].xaxis.set_ticks_position('both')
ax[0][1].xaxis.set_tick_params(labelsize=ticklabelsize)
ax[0][1].yaxis.set_tick_params(labelsize=ticklabelsize)

#ax[1][0]=plt.gca()
ax[1][0].get_yaxis().set_tick_params(which='both', direction='in')
ax[1][0].get_xaxis().set_tick_params(which='both', direction='in')
ax[1][0].yaxis.set_ticks_position('both')
ax[1][0].xaxis.set_ticks_position('both')
ax[1][0].xaxis.set_tick_params(labelsize=ticklabelsize)
ax[1][0].yaxis.set_tick_params(labelsize=ticklabelsize)

#ax[1][1]=plt.gca()
ax[1][1].get_yaxis().set_tick_params(which='both', direction='in')
ax[1][1].get_xaxis().set_tick_params(which='both', direction='in')
ax[1][1].yaxis.set_ticks_position('both')
ax[1][1].xaxis.set_ticks_position('both')
ax[1][1].xaxis.set_tick_params(labelsize=ticklabelsize)
ax[1][1].yaxis.set_tick_params(labelsize=ticklabelsize)

ax[0][0].set_xlim(PLOTRANGE[0],PLOTRANGE[1])
ax[0][0].set_ylim(PLOTRANGE[2],PLOTRANGE[3])
ax[0][0].set_aspect(0.55/ax[0][0].get_data_ratio())

ax[0][1].set_xlim(PLOTRANGE[0],PLOTRANGE[1])
ax[0][1].set_ylim(PLOTRANGE[2],PLOTRANGE[3])
ax[0][1].set_aspect(0.55/ax[0][0].get_data_ratio())

ax[1][0].set_xlim(PLOTRANGE[0],PLOTRANGE[1])
ax[1][0].set_ylim(PLOTRANGE[2],PLOTRANGE[3])
ax[1][0].set_aspect(0.55/ax[0][0].get_data_ratio())

ax[1][1].set_xlim(PLOTRANGE[0],PLOTRANGE[1])
ax[1][1].set_ylim(PLOTRANGE[2],PLOTRANGE[3])
ax[1][1].set_aspect(0.55/ax[0][0].get_data_ratio())

ax[0][0].plot(dataniki10[:,0],dataniki10[:,1],'-',color=tableau20[0],lw=3, label=r'$x_{CCN}$=0.10')
ax[0][0].plot(dataniki50[:,0],dataniki50[:,1],'-',color=tableau20[1],lw=3, label=r'$x_{CCN}$=0.50')
#ax[0][0].plot(dataniki90[:,0],dataniki90[:,1],'-',color=tableau20[2],lw=3, label=r'$x_{CCN}$=0.90')
ax[0][0].legend(loc='upper right',frameon=True,shadow=False,edgecolor='black',fancybox=False,framealpha=1.0,fontsize=0.7*legendlabelsize)

ax[0][0].text(.90, .15, r'a)', transform=ax[0][0].transAxes, ha="left", va="top",fontsize=axislabelsize)
plt.xticks(np.arange(PLOTRANGE[0]+0.1, PLOTRANGE[1]+0.1, 0.1))


ax[0][1].plot(datagrab10[:,0],datagrab10[:,1],'-',color=tableau20[0],lw=3, label=r'$x_{CCN}$=0.10')
ax[0][1].plot(datagrab50[:,0],datagrab50[:,1],'-',color=tableau20[1],lw=3, label=r'$x_{CCN}$=0.50')
#ax[0][1].plot(datagrab90[:,0],datagrab90[:,1],'-',color=tableau20[2],lw=3, label=r'$x_{CCN}$=0.90')
ax[0][1].legend(loc='upper right',frameon=True,shadow=False,edgecolor='black',fancybox=False,framealpha=1.0,fontsize=0.7*legendlabelsize)

ax[0][1].text(.90, .15, r'b)', transform=ax[0][1].transAxes, ha="left", va="top",fontsize=axislabelsize)
plt.xticks(np.arange(PLOTRANGE[0]+0.1, PLOTRANGE[1]+0.1, 0.1))


ax[1][0].plot(datakalu10[:,0],datakalu10[:,1],'-',color=tableau20[0],lw=3, label=r'$x_{CCN}$=0.10')
ax[1][0].plot(datakalu50[:,0],datakalu50[:,1],'-',color=tableau20[1],lw=3, label=r'$x_{CCN}$=0.50')
#ax[1][0].plot(datakalu90[:,0],datakalu90[:,1],'-',color=tableau20[2],lw=3, label=r'$x_{CCN}$=0.90')
ax[1][0].legend(loc='upper right',frameon=True,shadow=False,edgecolor='black',fancybox=False,framealpha=1.0,fontsize=0.7*legendlabelsize)

ax[1][0].text(.90, .15, r'c)', transform=ax[1][0].transAxes, ha="left", va="top",fontsize=axislabelsize)
plt.sca(ax[1, 0])
plt.xticks(np.arange(PLOTRANGE[0]+0.1, PLOTRANGE[1]+0.1, 0.1))


ax[1][1].plot(datakows10[:,0],datakows10[:,1],'-',color=tableau20[0],lw=3, label=r'$x_{CCN}$=0.10')
ax[1][1].plot(datakows50[:,0],datakows50[:,1],'-',color=tableau20[1],lw=3, label=r'$x_{CCN}$=0.50')
#ax[1][1].plot(datakows90[:,0],datakows90[:,1],'-',color=tableau20[2],lw=3, label=r'$x_{CCN}$=0.90')
ax[1][1].legend(loc='upper right',frameon=True,shadow=False,edgecolor='black',fancybox=False,framealpha=1.0,fontsize=0.7*legendlabelsize)

ax[1][1].text(.90, .15, r'd)', transform=ax[1][1].transAxes, ha="left", va="top",fontsize=axislabelsize)
plt.sca(ax[1, 1])
plt.xticks(np.arange(PLOTRANGE[0]+0.1, PLOTRANGE[1]+0.1, 0.1))



ax[0][0].set_ylabel(r'g(r)', fontsize=axislabelsize) # Y label
ax[1][0].set_ylabel(r'g(r)', fontsize=axislabelsize) # Y label
ax[1][0].set_xlabel(r'$r_{\rm}$ [nm]', fontsize=axislabelsize) # X label
ax[1][1].set_xlabel(r'$r_{\rm}$ [nm]', fontsize=axislabelsize) # X label


fig.suptitle('$O_{W}-H_{W}$', fontsize=16)
plt.tight_layout()
plt.savefig("rdf_ow_hw_10_50.png",bbox_inches='tight',dpi=600)

# %%
dataniki10=np.loadtxt("/localscratch/asourpis/metadata_MOGON/ff_evalution/niki/10/rdf_ow_h.xvg")
dataniki50=np.loadtxt("/localscratch/asourpis/metadata_MOGON/ff_evalution/niki/50/rdf_ow_h.xvg")
dataniki90=np.loadtxt("/localscratch/asourpis/metadata_MOGON/ff_evalution/niki/90/rdf_ow_h.xvg")

datakows10=np.loadtxt("/localscratch/asourpis/metadata_MOGON/ff_evalution/kows/10/rdf_ow_h.xvg")
datakows50=np.loadtxt("/localscratch/asourpis/metadata_MOGON/ff_evalution/kows/50/rdf_ow_h.xvg")
datakows90=np.loadtxt("/localscratch/asourpis/metadata_MOGON/ff_evalution/kows/90/rdf_ow_h.xvg")

datagrab10=np.loadtxt("/localscratch/asourpis/metadata_MOGON/ff_evalution/grab/10/rdf_ow_h.xvg")
datagrab50=np.loadtxt("/localscratch/asourpis/metadata_MOGON/ff_evalution/grab/50/rdf_ow_h.xvg")
datagrab90=np.loadtxt("/localscratch/asourpis/metadata_MOGON/ff_evalution/grab/90/rdf_ow_h.xvg")

datakalu10=np.loadtxt("/localscratch/asourpis/metadata_MOGON/ff_evalution/kalu/10/rdf_ow_h.xvg")
datakalu50=np.loadtxt("/localscratch/asourpis/metadata_MOGON/ff_evalution/kalu/50/rdf_ow_h.xvg")
datakalu90=np.loadtxt("/localscratch/asourpis/metadata_MOGON/ff_evalution/kalu/90/rdf_ow_h.xvg")

# %%
dataniki10[125:175,1]
# Out:
# array([0.276, 0.316, 0.362, 0.399, 0.445, 0.484, 0.523, 0.56 , 0.594,
#        0.621, 0.652, 0.689, 0.706, 0.733, 0.748, 0.77 , 0.784, 0.797,
#        0.808, 0.82 , 0.83 , 0.836, 0.842, 0.85 , 0.86 , 0.858, 0.864,
#        0.864, 0.87 , 0.871, 0.874, 0.875, 0.879, 0.875, 0.874, 0.87 ,
#        0.874, 0.874, 0.87 , 0.875, 0.873, 0.865, 0.871, 0.871, 0.87 ,
#        0.866, 0.866, 0.869, 0.863, 0.866])

# %%
dnniki10_ow_h=dataniki10[125:175,1]*0.02
dnniki50_ow_h=dataniki10[125:175,1]*0.02
dnniki90_ow_h=dataniki10[125:175,1]*0.02

nniki10_ow_h=sum(dnniki10_ow_h)
nniki10_ow_h=sum(dnniki50_ow_h)
nniki90_ow_h=sum(dnniki90_ow_h)

[nniki10_ow_h,nniki10_ow_h,nniki90_ow_h]
# Out:
# [0.7610400000000002, 0.7610400000000002, 0.7610400000000002]

# %%
dnkows10_ow_h=datakows10[125:175,1]*0.02
dnkows50_ow_h=datakows10[125:175,1]*0.02
dnkows90_ow_h=datakows10[125:175,1]*0.02

nkows10_ow_h=sum(dnkows10_ow_h)
nkows10_ow_h=sum(dnkows50_ow_h)
nkows90_ow_h=sum(dnkows90_ow_h)

[nkows10_ow_h,nkows10_ow_h,nkows90_ow_h]
# Out:
# [0.7429399999999998, 0.7429399999999998, 0.7429399999999998]

# %%
dngrab10_ow_h=datagrab10[125:175,1]*0.02
dngrab50_ow_h=datagrab10[125:175,1]*0.02
dngrab90_ow_h=datagrab10[125:175,1]*0.02

ngrab10_ow_h=sum(dngrab10_ow_h)
ngrab10_ow_h=sum(dngrab50_ow_h)
ngrab90_ow_h=sum(dngrab90_ow_h)

[ngrab10_ow_h,ngrab10_ow_h,ngrab90_ow_h]
# Out:
# [0.75854, 0.75854, 0.75854]

# %%
dnkalu10_ow_h=datakalu10[125:225,1]*0.02
dnkalu50_ow_h=datakalu10[125:225,1]*0.02
dnkalu90_ow_h=datakalu10[125:225,1]*0.02

nkalu10_ow_h=sum(dnkalu10_ow_h)
nkalu10_ow_h=sum(dnkalu50_ow_h)
nkalu90_ow_h=sum(dnkalu90_ow_h)

[nkalu10_ow_h,nkalu10_ow_h,nkalu90_ow_h]
# Out:
# [1.8223600000000004, 1.8223600000000004, 1.8223600000000004]

# %%
fig, ax = plt.subplots(2, 2, sharex='col', sharey='row')

PLOTRANGE = (0.15,0.6,0,1.5)
x = np.linspace(PLOTRANGE[0],PLOTRANGE[1],1000)

ax[0][0].get_yaxis().set_tick_params(which='both', direction='in')
ax[0][0].get_xaxis().set_tick_params(which='both', direction='in')
ax[0][0].yaxis.set_ticks_position('both')
ax[0][0].xaxis.set_ticks_position('both')
ax[0][0].xaxis.set_tick_params(labelsize=ticklabelsize)
ax[0][0].yaxis.set_tick_params(labelsize=ticklabelsize)

#ax[0][1]=plt.gca()
ax[0][1].get_yaxis().set_tick_params(which='both', direction='in')
ax[0][1].get_xaxis().set_tick_params(which='both', direction='in')
ax[0][1].yaxis.set_ticks_position('both')
ax[0][1].xaxis.set_ticks_position('both')
ax[0][1].xaxis.set_tick_params(labelsize=ticklabelsize)
ax[0][1].yaxis.set_tick_params(labelsize=ticklabelsize)

#ax[1][0]=plt.gca()
ax[1][0].get_yaxis().set_tick_params(which='both', direction='in')
ax[1][0].get_xaxis().set_tick_params(which='both', direction='in')
ax[1][0].yaxis.set_ticks_position('both')
ax[1][0].xaxis.set_ticks_position('both')
ax[1][0].xaxis.set_tick_params(labelsize=ticklabelsize)
ax[1][0].yaxis.set_tick_params(labelsize=ticklabelsize)

#ax[1][1]=plt.gca()
ax[1][1].get_yaxis().set_tick_params(which='both', direction='in')
ax[1][1].get_xaxis().set_tick_params(which='both', direction='in')
ax[1][1].yaxis.set_ticks_position('both')
ax[1][1].xaxis.set_ticks_position('both')
ax[1][1].xaxis.set_tick_params(labelsize=ticklabelsize)
ax[1][1].yaxis.set_tick_params(labelsize=ticklabelsize)

ax[0][0].set_xlim(PLOTRANGE[0],PLOTRANGE[1])
ax[0][0].set_ylim(PLOTRANGE[2],PLOTRANGE[3])
ax[0][0].set_aspect(0.55/ax[0][0].get_data_ratio())

ax[0][1].set_xlim(PLOTRANGE[0],PLOTRANGE[1])
ax[0][1].set_ylim(PLOTRANGE[2],PLOTRANGE[3])
ax[0][1].set_aspect(0.55/ax[0][0].get_data_ratio())

ax[1][0].set_xlim(PLOTRANGE[0],PLOTRANGE[1])
ax[1][0].set_ylim(PLOTRANGE[2],PLOTRANGE[3])
ax[1][0].set_aspect(0.55/ax[0][0].get_data_ratio())

ax[1][1].set_xlim(PLOTRANGE[0],PLOTRANGE[1])
ax[1][1].set_ylim(PLOTRANGE[2],PLOTRANGE[3])
ax[1][1].set_aspect(0.55/ax[0][0].get_data_ratio())

ax[0][0].plot(dataniki10[:,0],dataniki10[:,1],'-',color=tableau20[0],lw=2, label=r'$x_{CCN}$=0.10')
ax[0][0].plot(dataniki50[:,0],dataniki50[:,1],'-',color=tableau20[1],lw=2, label=r'$x_{CCN}$=0.50')
ax[0][0].plot(dataniki90[:,0],dataniki90[:,1],'-',color=tableau20[2],lw=2, label=r'$x_{CCN}$=0.90')
ax[0][0].legend(loc='lower right',frameon=True,shadow=False,edgecolor='black',fancybox=False,framealpha=1.0,fontsize=0.65*legendlabelsize)

ax[0][0].text(.05, .90, r'a)', transform=ax[0][0].transAxes, ha="left", va="top",fontsize=axislabelsize)
plt.xticks(np.arange(PLOTRANGE[0]+0.1, PLOTRANGE[1]+0.1, 0.1))


ax[0][1].plot(datagrab10[:,0],datagrab10[:,1],'-',color=tableau20[0],lw=2, label=r'$x_{CCN}$=0.10')
ax[0][1].plot(datagrab50[:,0],datagrab50[:,1],'-',color=tableau20[1],lw=2, label=r'$x_{CCN}$=0.50')
ax[0][1].plot(datagrab90[:,0],datagrab90[:,1],'-',color=tableau20[2],lw=2, label=r'$x_{CCN}$=0.90')
ax[0][1].legend(loc='lower right',frameon=True,shadow=False,edgecolor='black',fancybox=False,framealpha=1.0,fontsize=0.65*legendlabelsize)

ax[0][1].text(.05, .90, r'b)', transform=ax[0][1].transAxes, ha="left", va="top",fontsize=axislabelsize)
plt.xticks(np.arange(PLOTRANGE[0]+0.1, PLOTRANGE[1]+0.1, 0.1))


ax[1][0].plot(datakalu10[:,0],datakalu10[:,1],'-',color=tableau20[0],lw=2, label=r'$x_{CCN}$=0.10')
ax[1][0].plot(datakalu50[:,0],datakalu50[:,1],'-',color=tableau20[1],lw=2, label=r'$x_{CCN}$=0.50')
ax[1][0].plot(datakalu90[:,0],datakalu90[:,1],'-',color=tableau20[2],lw=2, label=r'$x_{CCN}$=0.90')
ax[1][0].legend(loc='lower right',frameon=True,shadow=False,edgecolor='black',fancybox=False,framealpha=1.0,fontsize=0.65*legendlabelsize)

ax[1][0].text(.05, .90, r'c)', transform=ax[1][0].transAxes, ha="left", va="top",fontsize=axislabelsize)
plt.sca(ax[1, 0])
plt.xticks(np.arange(PLOTRANGE[0]+0.1, PLOTRANGE[1]+0.1, 0.1))


ax[1][1].plot(datakows10[:,0],datakows10[:,1],'-',color=tableau20[0],lw=2, label=r'$x_{CCN}$=0.10')
ax[1][1].plot(datakows50[:,0],datakows50[:,1],'-',color=tableau20[1],lw=2, label=r'$x_{CCN}$=0.50')
ax[1][1].plot(datakows90[:,0],datakows90[:,1],'-',color=tableau20[2],lw=2, label=r'$x_{CCN}$=0.90')
ax[1][1].legend(loc='lower right',frameon=True,shadow=False,edgecolor='black',fancybox=False,framealpha=1.0,fontsize=0.65*legendlabelsize)

ax[1][1].text(.05, .90, r'd)', transform=ax[1][1].transAxes, ha="left", va="top",fontsize=axislabelsize)
plt.sca(ax[1, 1])
plt.xticks(np.arange(PLOTRANGE[0]+0.1, PLOTRANGE[1]+0.1, 0.1))



ax[0][0].set_ylabel(r'g(r)', fontsize=axislabelsize) # Y label
ax[1][0].set_ylabel(r'g(r)', fontsize=axislabelsize) # Y label
ax[1][0].set_xlabel(r'$r_{\rm}$ [nm]', fontsize=axislabelsize) # X label
ax[1][1].set_xlabel(r'$r_{\rm}$ [nm]', fontsize=axislabelsize) # X label


fig.suptitle('$O_{W}-H_{CCN}$', fontsize=16)
plt.tight_layout()
#plt.savefig("rdf_ow_hccn.png",bbox_inches='tight',dpi=600)

# %%
dataniki10=np.loadtxt("/localscratch/asourpis/metadata_MOGON/ff_evalution/niki_corr/10/rdf_c1_c1.xvg",comments=['#','@'])
dataniki50=np.loadtxt("/localscratch/asourpis/metadata_MOGON/ff_evalution/niki_corr/50/rdf_c1_c1.xvg",comments=['#','@'])
dataniki90=np.loadtxt("/localscratch/asourpis/metadata_MOGON/ff_evalution/niki_corr/90/rdf_c1_c1.xvg",comments=['#','@'])

datakows10=np.loadtxt("/localscratch/asourpis/metadata_MOGON/ff_evalution/kows/10/rdf_c1_c1.xvg")
datakows50=np.loadtxt("/localscratch/asourpis/metadata_MOGON/ff_evalution/kows/50/rdf_c1_c1.xvg")
datakows90=np.loadtxt("/localscratch/asourpis/metadata_MOGON/ff_evalution/kows/90/rdf_c1_c1.xvg")

datagrab10=np.loadtxt("/localscratch/asourpis/metadata_MOGON/ff_evalution/grab_corr/10/rdf_c1_c1.xvg",comments=['#','@'])
datagrab50=np.loadtxt("/localscratch/asourpis/metadata_MOGON/ff_evalution/grab_corr/50/rdf_c1_c1.xvg",comments=['#','@'])
datagrab90=np.loadtxt("/localscratch/asourpis/metadata_MOGON/ff_evalution/grab_corr/90/rdf_c1_c1.xvg",comments=['#','@'])

datakalu10=np.loadtxt("/localscratch/asourpis/metadata_MOGON/ff_evalution/kalu/10/rdf_c1_c1.xvg")
datakalu50=np.loadtxt("/localscratch/asourpis/metadata_MOGON/ff_evalution/kalu/50/rdf_c1_c1.xvg")
datakalu90=np.loadtxt("/localscratch/asourpis/metadata_MOGON/ff_evalution/kalu/90/rdf_c1_c1.xvg")

# %%
fig, ax = plt.subplots(2, 2, sharex='col', sharey='row')

PLOTRANGE = (0.25,1.0,0,2.2)
x = np.linspace(PLOTRANGE[0],PLOTRANGE[1],1000)

ax[0][0].get_yaxis().set_tick_params(which='both', direction='in')
ax[0][0].get_xaxis().set_tick_params(which='both', direction='in')
ax[0][0].yaxis.set_ticks_position('both')
ax[0][0].xaxis.set_ticks_position('both')
ax[0][0].xaxis.set_tick_params(labelsize=ticklabelsize)
ax[0][0].yaxis.set_tick_params(labelsize=ticklabelsize)

#ax[0][1]=plt.gca()
ax[0][1].get_yaxis().set_tick_params(which='both', direction='in')
ax[0][1].get_xaxis().set_tick_params(which='both', direction='in')
ax[0][1].yaxis.set_ticks_position('both')
ax[0][1].xaxis.set_ticks_position('both')
ax[0][1].xaxis.set_tick_params(labelsize=ticklabelsize)
ax[0][1].yaxis.set_tick_params(labelsize=ticklabelsize)

#ax[1][0]=plt.gca()
ax[1][0].get_yaxis().set_tick_params(which='both', direction='in')
ax[1][0].get_xaxis().set_tick_params(which='both', direction='in')
ax[1][0].yaxis.set_ticks_position('both')
ax[1][0].xaxis.set_ticks_position('both')
ax[1][0].xaxis.set_tick_params(labelsize=ticklabelsize)
ax[1][0].yaxis.set_tick_params(labelsize=ticklabelsize)

#ax[1][1]=plt.gca()
ax[1][1].get_yaxis().set_tick_params(which='both', direction='in')
ax[1][1].get_xaxis().set_tick_params(which='both', direction='in')
ax[1][1].yaxis.set_ticks_position('both')
ax[1][1].xaxis.set_ticks_position('both')
ax[1][1].xaxis.set_tick_params(labelsize=ticklabelsize)
ax[1][1].yaxis.set_tick_params(labelsize=ticklabelsize)

ax[0][0].set_xlim(PLOTRANGE[0],PLOTRANGE[1])
ax[0][0].set_ylim(PLOTRANGE[2],PLOTRANGE[3])
ax[0][0].set_aspect(0.55/ax[0][0].get_data_ratio())

ax[0][1].set_xlim(PLOTRANGE[0],PLOTRANGE[1])
ax[0][1].set_ylim(PLOTRANGE[2],PLOTRANGE[3])
ax[0][1].set_aspect(0.55/ax[0][0].get_data_ratio())

ax[1][0].set_xlim(PLOTRANGE[0],PLOTRANGE[1])
ax[1][0].set_ylim(PLOTRANGE[2],PLOTRANGE[3])
ax[1][0].set_aspect(0.55/ax[0][0].get_data_ratio())

ax[1][1].set_xlim(PLOTRANGE[0],PLOTRANGE[1])
ax[1][1].set_ylim(PLOTRANGE[2],PLOTRANGE[3])
ax[1][1].set_aspect(0.55/ax[0][0].get_data_ratio())

ax[0][0].plot(dataniki10[:,0],dataniki10[:,1],'-',color=tableau20[0],lw=2, label=r'$x_{CCN}$=0.10')
ax[0][0].plot(dataniki50[:,0],dataniki50[:,1],'-',color=tableau20[1],lw=2, label=r'$x_{CCN}$=0.50')
ax[0][0].plot(dataniki90[:,0],dataniki90[:,1],'-',color=tableau20[2],lw=2, label=r'$x_{CCN}$=0.90')
ax[0][0].legend(loc='upper right',frameon=True,shadow=False,edgecolor='black',fancybox=False,framealpha=1.0,fontsize=0.65*legendlabelsize)

ax[0][0].text(.05, .90, r'a)', transform=ax[0][0].transAxes, ha="left", va="top",fontsize=axislabelsize)
plt.xticks(np.arange(PLOTRANGE[0]+0.1, PLOTRANGE[1]+0.1, 0.1))


ax[0][1].plot(datagrab10[:,0],datagrab10[:,1],'-',color=tableau20[0],lw=2, label=r'$x_{CCN}$=0.10')
ax[0][1].plot(datagrab50[:,0],datagrab50[:,1],'-',color=tableau20[1],lw=2, label=r'$x_{CCN}$=0.50')
ax[0][1].plot(datagrab90[:,0],datagrab90[:,1],'-',color=tableau20[2],lw=2, label=r'$x_{CCN}$=0.90')
ax[0][1].legend(loc='upper right',frameon=True,shadow=False,edgecolor='black',fancybox=False,framealpha=1.0,fontsize=0.65*legendlabelsize)

ax[0][1].text(.05, .90, r'b)', transform=ax[0][1].transAxes, ha="left", va="top",fontsize=axislabelsize)
plt.xticks(np.arange(PLOTRANGE[0]+0.1, PLOTRANGE[1]+0.1, 0.1))


ax[1][0].plot(datakalu10[:,0],datakalu10[:,1],'-',color=tableau20[0],lw=2, label=r'$x_{CCN}$=0.10')
ax[1][0].plot(datakalu50[:,0],datakalu50[:,1],'-',color=tableau20[1],lw=2, label=r'$x_{CCN}$=0.50')
ax[1][0].plot(datakalu90[:,0],datakalu90[:,1],'-',color=tableau20[2],lw=2, label=r'$x_{CCN}$=0.90')
ax[1][0].legend(loc='upper right',frameon=True,shadow=False,edgecolor='black',fancybox=False,framealpha=1.0,fontsize=0.65*legendlabelsize)

ax[1][0].text(.05, .90, r'c)', transform=ax[1][0].transAxes, ha="left", va="top",fontsize=axislabelsize)
plt.sca(ax[1, 0])
plt.xticks(np.arange(PLOTRANGE[0]+0.1, PLOTRANGE[1]+0.1, 0.1))


ax[1][1].plot(datakows10[:,0],datakows10[:,1],'-',color=tableau20[0],lw=2, label=r'$x_{CCN}$=0.10')
ax[1][1].plot(datakows50[:,0],datakows50[:,1],'-',color=tableau20[1],lw=2, label=r'$x_{CCN}$=0.50')
ax[1][1].plot(datakows90[:,0],datakows90[:,1],'-',color=tableau20[2],lw=2, label=r'$x_{CCN}$=0.90')
ax[1][1].legend(loc='upper right',frameon=True,shadow=False,edgecolor='black',fancybox=False,framealpha=1.0,fontsize=0.65*legendlabelsize)

ax[1][1].text(.05, .90, r'd)', transform=ax[1][1].transAxes, ha="left", va="top",fontsize=axislabelsize)
plt.sca(ax[1, 1])
plt.xticks(np.arange(PLOTRANGE[0]+0.1, PLOTRANGE[1]+0.1, 0.1))



ax[0][0].set_ylabel(r'g(r)', fontsize=axislabelsize) # Y label
ax[1][0].set_ylabel(r'g(r)', fontsize=axislabelsize) # Y label
ax[1][0].set_xlabel(r'$r_{\rm}$ [nm]', fontsize=axislabelsize) # X label
ax[1][1].set_xlabel(r'$r_{\rm}$ [nm]', fontsize=axislabelsize) # X label


fig.suptitle('$C_{1}-C_{1}$', fontsize=16)
plt.tight_layout()
plt.savefig("corr_si_rdf_c1_c1.png",bbox_inches='tight',dpi=600)

# %%
dataniki10=np.loadtxt("/localscratch/asourpis/metadata_MOGON/ff_evalution/niki_corr/10/rdf_c2_c2.xvg",comments=['#','@'])
dataniki50=np.loadtxt("/localscratch/asourpis/metadata_MOGON/ff_evalution/niki_corr/50/rdf_c2_c2.xvg",comments=['#','@'])
dataniki90=np.loadtxt("/localscratch/asourpis/metadata_MOGON/ff_evalution/niki_corr/90/rdf_c2_c2.xvg",comments=['#','@'])

datakows10=np.loadtxt("/localscratch/asourpis/metadata_MOGON/ff_evalution/kows/10/rdf_c2_c2.xvg")
datakows50=np.loadtxt("/localscratch/asourpis/metadata_MOGON/ff_evalution/kows/50/rdf_c2_c2.xvg")
datakows90=np.loadtxt("/localscratch/asourpis/metadata_MOGON/ff_evalution/kows/90/rdf_c2_c2.xvg")

datagrab10=np.loadtxt("/localscratch/asourpis/metadata_MOGON/ff_evalution/grab_corr/10/rdf_c2_c2.xvg",comments=['#','@'])
datagrab50=np.loadtxt("/localscratch/asourpis/metadata_MOGON/ff_evalution/grab_corr/50/rdf_c2_c2.xvg",comments=['#','@'])
datagrab90=np.loadtxt("/localscratch/asourpis/metadata_MOGON/ff_evalution/grab_corr/90/rdf_c2_c2.xvg",comments=['#','@'])

datakalu10=np.loadtxt("/localscratch/asourpis/metadata_MOGON/ff_evalution/kalu/10/rdf_c2_c2.xvg")
datakalu50=np.loadtxt("/localscratch/asourpis/metadata_MOGON/ff_evalution/kalu/50/rdf_c2_c2.xvg")
datakalu90=np.loadtxt("/localscratch/asourpis/metadata_MOGON/ff_evalution/kalu/90/rdf_c2_c2.xvg")

# %%
fig, ax = plt.subplots(2, 2, sharex='col', sharey='row')

PLOTRANGE = (0.3,1.0,0,2.5)
x = np.linspace(PLOTRANGE[0],PLOTRANGE[1],1000)

ax[0][0].get_yaxis().set_tick_params(which='both', direction='in')
ax[0][0].get_xaxis().set_tick_params(which='both', direction='in')
ax[0][0].yaxis.set_ticks_position('both')
ax[0][0].xaxis.set_ticks_position('both')
ax[0][0].xaxis.set_tick_params(labelsize=ticklabelsize)
ax[0][0].yaxis.set_tick_params(labelsize=ticklabelsize)

#ax[0][1]=plt.gca()
ax[0][1].get_yaxis().set_tick_params(which='both', direction='in')
ax[0][1].get_xaxis().set_tick_params(which='both', direction='in')
ax[0][1].yaxis.set_ticks_position('both')
ax[0][1].xaxis.set_ticks_position('both')
ax[0][1].xaxis.set_tick_params(labelsize=ticklabelsize)
ax[0][1].yaxis.set_tick_params(labelsize=ticklabelsize)

#ax[1][0]=plt.gca()
ax[1][0].get_yaxis().set_tick_params(which='both', direction='in')
ax[1][0].get_xaxis().set_tick_params(which='both', direction='in')
ax[1][0].yaxis.set_ticks_position('both')
ax[1][0].xaxis.set_ticks_position('both')
ax[1][0].xaxis.set_tick_params(labelsize=ticklabelsize)
ax[1][0].yaxis.set_tick_params(labelsize=ticklabelsize)

#ax[1][1]=plt.gca()
ax[1][1].get_yaxis().set_tick_params(which='both', direction='in')
ax[1][1].get_xaxis().set_tick_params(which='both', direction='in')
ax[1][1].yaxis.set_ticks_position('both')
ax[1][1].xaxis.set_ticks_position('both')
ax[1][1].xaxis.set_tick_params(labelsize=ticklabelsize)
ax[1][1].yaxis.set_tick_params(labelsize=ticklabelsize)

ax[0][0].set_xlim(PLOTRANGE[0],PLOTRANGE[1])
ax[0][0].set_ylim(PLOTRANGE[2],PLOTRANGE[3])
ax[0][0].set_aspect(0.55/ax[0][0].get_data_ratio())

ax[0][1].set_xlim(PLOTRANGE[0],PLOTRANGE[1])
ax[0][1].set_ylim(PLOTRANGE[2],PLOTRANGE[3])
ax[0][1].set_aspect(0.55/ax[0][0].get_data_ratio())

ax[1][0].set_xlim(PLOTRANGE[0],PLOTRANGE[1])
ax[1][0].set_ylim(PLOTRANGE[2],PLOTRANGE[3])
ax[1][0].set_aspect(0.55/ax[0][0].get_data_ratio())

ax[1][1].set_xlim(PLOTRANGE[0],PLOTRANGE[1])
ax[1][1].set_ylim(PLOTRANGE[2],PLOTRANGE[3])
ax[1][1].set_aspect(0.55/ax[0][0].get_data_ratio())

ax[0][0].plot(dataniki10[:,0],dataniki10[:,1],'-',color=tableau20[0],lw=2, label=r'$x_{CCN}$=0.10')
ax[0][0].plot(dataniki50[:,0],dataniki50[:,1],'-',color=tableau20[1],lw=2, label=r'$x_{CCN}$=0.50')
ax[0][0].plot(dataniki90[:,0],dataniki90[:,1],'-',color=tableau20[2],lw=2, label=r'$x_{CCN}$=0.90')
ax[0][0].legend(loc='upper right',frameon=True,shadow=False,edgecolor='black',fancybox=False,framealpha=1.0,fontsize=0.65*legendlabelsize)

ax[0][0].text(.05, .90, r'a)', transform=ax[0][0].transAxes, ha="left", va="top",fontsize=axislabelsize)
plt.xticks(np.arange(PLOTRANGE[0]+0.1, PLOTRANGE[1]+0.1, 0.1))


ax[0][1].plot(datagrab10[:,0],datagrab10[:,1],'-',color=tableau20[0],lw=2, label=r'$x_{CCN}$=0.10')
ax[0][1].plot(datagrab50[:,0],datagrab50[:,1],'-',color=tableau20[1],lw=2, label=r'$x_{CCN}$=0.50')
ax[0][1].plot(datagrab90[:,0],datagrab90[:,1],'-',color=tableau20[2],lw=2, label=r'$x_{CCN}$=0.90')
ax[0][1].legend(loc='upper right',frameon=True,shadow=False,edgecolor='black',fancybox=False,framealpha=1.0,fontsize=0.65*legendlabelsize)

ax[0][1].text(.05, .90, r'b)', transform=ax[0][1].transAxes, ha="left", va="top",fontsize=axislabelsize)
plt.xticks(np.arange(PLOTRANGE[0]+0.1, PLOTRANGE[1]+0.1, 0.1))


ax[1][0].plot(datakalu10[:,0],datakalu10[:,1],'-',color=tableau20[0],lw=2, label=r'$x_{CCN}$=0.10')
ax[1][0].plot(datakalu50[:,0],datakalu50[:,1],'-',color=tableau20[1],lw=2, label=r'$x_{CCN}$=0.50')
ax[1][0].plot(datakalu90[:,0],datakalu90[:,1],'-',color=tableau20[2],lw=2, label=r'$x_{CCN}$=0.90')
ax[1][0].legend(loc='upper right',frameon=True,shadow=False,edgecolor='black',fancybox=False,framealpha=1.0,fontsize=0.65*legendlabelsize)

ax[1][0].text(.05, .90, r'c)', transform=ax[1][0].transAxes, ha="left", va="top",fontsize=axislabelsize)
plt.sca(ax[1, 0])
plt.xticks(np.arange(PLOTRANGE[0]+0.1, PLOTRANGE[1]+0.1, 0.1))


ax[1][1].plot(datakows10[:,0],datakows10[:,1],'-',color=tableau20[0],lw=2, label=r'$x_{CCN}$=0.10')
ax[1][1].plot(datakows50[:,0],datakows50[:,1],'-',color=tableau20[1],lw=2, label=r'$x_{CCN}$=0.50')
ax[1][1].plot(datakows90[:,0],datakows90[:,1],'-',color=tableau20[2],lw=2, label=r'$x_{CCN}$=0.90')
ax[1][1].legend(loc='upper right',frameon=True,shadow=False,edgecolor='black',fancybox=False,framealpha=1.0,fontsize=0.65*legendlabelsize)

ax[1][1].text(.05, .90, r'd)', transform=ax[1][1].transAxes, ha="left", va="top",fontsize=axislabelsize)
plt.sca(ax[1, 1])
plt.xticks(np.arange(PLOTRANGE[0]+0.1, PLOTRANGE[1]+0.1, 0.1))



ax[0][0].set_ylabel(r'g(r)', fontsize=axislabelsize) # Y label
ax[1][0].set_ylabel(r'g(r)', fontsize=axislabelsize) # Y label
ax[1][0].set_xlabel(r'$r_{\rm}$ [nm]', fontsize=axislabelsize) # X label
ax[1][1].set_xlabel(r'$r_{\rm}$ [nm]', fontsize=axislabelsize) # X label


fig.suptitle('$C_{2}-C_{2}$', fontsize=16)
plt.tight_layout()
plt.savefig("corr_si_rdf_c2_c2.png",bbox_inches='tight',dpi=600)

# %%
dataniki10=np.loadtxt("/localscratch/asourpis/metadata_MOGON/ff_evalution/niki_corr/10/rdf_n1_n1.xvg",comments=['#','@'])
dataniki50=np.loadtxt("/localscratch/asourpis/metadata_MOGON/ff_evalution/niki_corr/50/rdf_n1_n1.xvg",comments=['#','@'])
dataniki90=np.loadtxt("/localscratch/asourpis/metadata_MOGON/ff_evalution/niki_corr/90/rdf_n1_n1.xvg",comments=['#','@'])

datakows10=np.loadtxt("/localscratch/asourpis/metadata_MOGON/ff_evalution/kows/10/rdf_n1_n1.xvg")
datakows50=np.loadtxt("/localscratch/asourpis/metadata_MOGON/ff_evalution/kows/50/rdf_n1_n1.xvg")
datakows90=np.loadtxt("/localscratch/asourpis/metadata_MOGON/ff_evalution/kows/90/rdf_n1_n1.xvg")

datagrab10=np.loadtxt("/localscratch/asourpis/metadata_MOGON/ff_evalution/grab_corr/10/rdf_n1_n1.xvg",comments=['#','@'])
datagrab50=np.loadtxt("/localscratch/asourpis/metadata_MOGON/ff_evalution/grab_corr/50/rdf_n1_n1.xvg",comments=['#','@'])
datagrab90=np.loadtxt("/localscratch/asourpis/metadata_MOGON/ff_evalution/grab_corr/90/rdf_n1_n1.xvg",comments=['#','@'])

datakalu10=np.loadtxt("/localscratch/asourpis/metadata_MOGON/ff_evalution/kalu/10/rdf_n1_n1.xvg")
datakalu50=np.loadtxt("/localscratch/asourpis/metadata_MOGON/ff_evalution/kalu/50/rdf_n1_n1.xvg")
datakalu90=np.loadtxt("/localscratch/asourpis/metadata_MOGON/ff_evalution/kalu/90/rdf_n1_n1.xvg")

# %%
fig, ax = plt.subplots(2, 2, sharex='col', sharey='row')

PLOTRANGE = (0.25,1.0,0,2.2)
x = np.linspace(PLOTRANGE[0],PLOTRANGE[1],1000)

ax[0][0].get_yaxis().set_tick_params(which='both', direction='in')
ax[0][0].get_xaxis().set_tick_params(which='both', direction='in')
ax[0][0].yaxis.set_ticks_position('both')
ax[0][0].xaxis.set_ticks_position('both')
ax[0][0].xaxis.set_tick_params(labelsize=ticklabelsize)
ax[0][0].yaxis.set_tick_params(labelsize=ticklabelsize)

#ax[0][1]=plt.gca()
ax[0][1].get_yaxis().set_tick_params(which='both', direction='in')
ax[0][1].get_xaxis().set_tick_params(which='both', direction='in')
ax[0][1].yaxis.set_ticks_position('both')
ax[0][1].xaxis.set_ticks_position('both')
ax[0][1].xaxis.set_tick_params(labelsize=ticklabelsize)
ax[0][1].yaxis.set_tick_params(labelsize=ticklabelsize)

#ax[1][0]=plt.gca()
ax[1][0].get_yaxis().set_tick_params(which='both', direction='in')
ax[1][0].get_xaxis().set_tick_params(which='both', direction='in')
ax[1][0].yaxis.set_ticks_position('both')
ax[1][0].xaxis.set_ticks_position('both')
ax[1][0].xaxis.set_tick_params(labelsize=ticklabelsize)
ax[1][0].yaxis.set_tick_params(labelsize=ticklabelsize)

#ax[1][1]=plt.gca()
ax[1][1].get_yaxis().set_tick_params(which='both', direction='in')
ax[1][1].get_xaxis().set_tick_params(which='both', direction='in')
ax[1][1].yaxis.set_ticks_position('both')
ax[1][1].xaxis.set_ticks_position('both')
ax[1][1].xaxis.set_tick_params(labelsize=ticklabelsize)
ax[1][1].yaxis.set_tick_params(labelsize=ticklabelsize)

ax[0][0].set_xlim(PLOTRANGE[0],PLOTRANGE[1])
ax[0][0].set_ylim(PLOTRANGE[2],PLOTRANGE[3])
ax[0][0].set_aspect(0.55/ax[0][0].get_data_ratio())

ax[0][1].set_xlim(PLOTRANGE[0],PLOTRANGE[1])
ax[0][1].set_ylim(PLOTRANGE[2],PLOTRANGE[3])
ax[0][1].set_aspect(0.55/ax[0][0].get_data_ratio())

ax[1][0].set_xlim(PLOTRANGE[0],PLOTRANGE[1])
ax[1][0].set_ylim(PLOTRANGE[2],PLOTRANGE[3])
ax[1][0].set_aspect(0.55/ax[0][0].get_data_ratio())

ax[1][1].set_xlim(PLOTRANGE[0],PLOTRANGE[1])
ax[1][1].set_ylim(PLOTRANGE[2],PLOTRANGE[3])
ax[1][1].set_aspect(0.55/ax[0][0].get_data_ratio())

ax[0][0].plot(dataniki10[:,0],dataniki10[:,1],'-',color=tableau20[0],lw=2, label=r'$x_{CCN}$=0.10')
ax[0][0].plot(dataniki50[:,0],dataniki50[:,1],'-',color=tableau20[1],lw=2, label=r'$x_{CCN}$=0.50')
ax[0][0].plot(dataniki90[:,0],dataniki90[:,1],'-',color=tableau20[2],lw=2, label=r'$x_{CCN}$=0.90')
ax[0][0].legend(loc='upper right',frameon=True,shadow=False,edgecolor='black',fancybox=False,framealpha=1.0,fontsize=0.65*legendlabelsize)

ax[0][0].text(.90, .25, r'a)', transform=ax[0][0].transAxes, ha="left", va="top",fontsize=axislabelsize)
plt.xticks(np.arange(PLOTRANGE[0]+0.1, PLOTRANGE[1]+0.1, 0.1))


ax[0][1].plot(datagrab10[:,0],datagrab10[:,1],'-',color=tableau20[0],lw=2, label=r'$x_{CCN}$=0.10')
ax[0][1].plot(datagrab50[:,0],datagrab50[:,1],'-',color=tableau20[1],lw=2, label=r'$x_{CCN}$=0.50')
ax[0][1].plot(datagrab90[:,0],datagrab90[:,1],'-',color=tableau20[2],lw=2, label=r'$x_{CCN}$=0.90')
ax[0][1].legend(loc='upper right',frameon=True,shadow=False,edgecolor='black',fancybox=False,framealpha=1.0,fontsize=0.65*legendlabelsize)

ax[0][1].text(.90, .25, r'b)', transform=ax[0][1].transAxes, ha="left", va="top",fontsize=axislabelsize)
plt.xticks(np.arange(PLOTRANGE[0]+0.1, PLOTRANGE[1]+0.1, 0.1))


ax[1][0].plot(datakalu10[:,0],datakalu10[:,1],'-',color=tableau20[0],lw=2, label=r'$x_{CCN}$=0.10')
ax[1][0].plot(datakalu50[:,0],datakalu50[:,1],'-',color=tableau20[1],lw=2, label=r'$x_{CCN}$=0.50')
ax[1][0].plot(datakalu90[:,0],datakalu90[:,1],'-',color=tableau20[2],lw=2, label=r'$x_{CCN}$=0.90')
ax[1][0].legend(loc='upper right',frameon=True,shadow=False,edgecolor='black',fancybox=False,framealpha=1.0,fontsize=0.65*legendlabelsize)

ax[1][0].text(.90, .25, r'c)', transform=ax[1][0].transAxes, ha="left", va="top",fontsize=axislabelsize)
plt.sca(ax[1, 0])
plt.xticks(np.arange(PLOTRANGE[0]+0.1, PLOTRANGE[1]+0.1, 0.1))


ax[1][1].plot(datakows10[:,0],datakows10[:,1],'-',color=tableau20[0],lw=2, label=r'$x_{CCN}$=0.10')
ax[1][1].plot(datakows50[:,0],datakows50[:,1],'-',color=tableau20[1],lw=2, label=r'$x_{CCN}$=0.50')
ax[1][1].plot(datakows90[:,0],datakows90[:,1],'-',color=tableau20[2],lw=2, label=r'$x_{CCN}$=0.90')
ax[1][1].legend(loc='upper right',frameon=True,shadow=False,edgecolor='black',fancybox=False,framealpha=1.0,fontsize=0.65*legendlabelsize)

ax[1][1].text(.90, .25, r'd)', transform=ax[1][1].transAxes, ha="left", va="top",fontsize=axislabelsize)
plt.sca(ax[1, 1])
plt.xticks(np.arange(PLOTRANGE[0]+0.1, PLOTRANGE[1]+0.1, 0.1))



ax[0][0].set_ylabel(r'g(r)', fontsize=axislabelsize) # Y label
ax[1][0].set_ylabel(r'g(r)', fontsize=axislabelsize) # Y label
ax[1][0].set_xlabel(r'$r_{\rm}$ [nm]', fontsize=axislabelsize) # X label
ax[1][1].set_xlabel(r'$r_{\rm}$ [nm]', fontsize=axislabelsize) # X label


fig.suptitle('$N-N$', fontsize=16)
plt.tight_layout()
plt.savefig("corr_si_rdf_n1_n1.png",bbox_inches='tight',dpi=600)

# %%
dataniki10=np.loadtxt("/localscratch/asourpis/metadata_MOGON/ff_evalution/niki/10/rdf_n1_ow.xvg")
dataniki50=np.loadtxt("/localscratch/asourpis/metadata_MOGON/ff_evalution/niki/50/rdf_n1_ow.xvg")
dataniki90=np.loadtxt("/localscratch/asourpis/metadata_MOGON/ff_evalution/niki/90/rdf_n1_ow.xvg")

datakows10=np.loadtxt("/localscratch/asourpis/metadata_MOGON/ff_evalution/kows/10/rdf_n1_ow.xvg")
datakows50=np.loadtxt("/localscratch/asourpis/metadata_MOGON/ff_evalution/kows/50/rdf_n1_ow.xvg")
datakows90=np.loadtxt("/localscratch/asourpis/metadata_MOGON/ff_evalution/kows/90/rdf_n1_ow.xvg")

datagrab10=np.loadtxt("/localscratch/asourpis/metadata_MOGON/ff_evalution/grab/10/rdf_n1_ow.xvg")
datagrab50=np.loadtxt("/localscratch/asourpis/metadata_MOGON/ff_evalution/grab/50/rdf_n1_ow.xvg")
datagrab90=np.loadtxt("/localscratch/asourpis/metadata_MOGON/ff_evalution/grab/90/rdf_n1_ow.xvg")

datakalu10=np.loadtxt("/localscratch/asourpis/metadata_MOGON/ff_evalution/kalu/10/rdf_n1_ow.xvg")
datakalu50=np.loadtxt("/localscratch/asourpis/metadata_MOGON/ff_evalution/kalu/50/rdf_n1_ow.xvg")
datakalu90=np.loadtxt("/localscratch/asourpis/metadata_MOGON/ff_evalution/kalu/90/rdf_n1_ow.xvg")

# %%
fig, ax = plt.subplots(2, 2, sharex='col', sharey='row')

PLOTRANGE = (0.2,0.6,0,3.0)
x = np.linspace(PLOTRANGE[0],PLOTRANGE[1],1000)

ax[0][0].get_yaxis().set_tick_params(which='both', direction='in')
ax[0][0].get_xaxis().set_tick_params(which='both', direction='in')
ax[0][0].yaxis.set_ticks_position('both')
ax[0][0].xaxis.set_ticks_position('both')
ax[0][0].xaxis.set_tick_params(labelsize=ticklabelsize)
ax[0][0].yaxis.set_tick_params(labelsize=ticklabelsize)

#ax[0][1]=plt.gca()
ax[0][1].get_yaxis().set_tick_params(which='both', direction='in')
ax[0][1].get_xaxis().set_tick_params(which='both', direction='in')
ax[0][1].yaxis.set_ticks_position('both')
ax[0][1].xaxis.set_ticks_position('both')
ax[0][1].xaxis.set_tick_params(labelsize=ticklabelsize)
ax[0][1].yaxis.set_tick_params(labelsize=ticklabelsize)

#ax[1][0]=plt.gca()
ax[1][0].get_yaxis().set_tick_params(which='both', direction='in')
ax[1][0].get_xaxis().set_tick_params(which='both', direction='in')
ax[1][0].yaxis.set_ticks_position('both')
ax[1][0].xaxis.set_ticks_position('both')
ax[1][0].xaxis.set_tick_params(labelsize=ticklabelsize)
ax[1][0].yaxis.set_tick_params(labelsize=ticklabelsize)

#ax[1][1]=plt.gca()
ax[1][1].get_yaxis().set_tick_params(which='both', direction='in')
ax[1][1].get_xaxis().set_tick_params(which='both', direction='in')
ax[1][1].yaxis.set_ticks_position('both')
ax[1][1].xaxis.set_ticks_position('both')
ax[1][1].xaxis.set_tick_params(labelsize=ticklabelsize)
ax[1][1].yaxis.set_tick_params(labelsize=ticklabelsize)

ax[0][0].set_xlim(PLOTRANGE[0],PLOTRANGE[1])
ax[0][0].set_ylim(PLOTRANGE[2],PLOTRANGE[3])
ax[0][0].set_aspect(0.55/ax[0][0].get_data_ratio())

ax[0][1].set_xlim(PLOTRANGE[0],PLOTRANGE[1])
ax[0][1].set_ylim(PLOTRANGE[2],PLOTRANGE[3])
ax[0][1].set_aspect(0.55/ax[0][0].get_data_ratio())

ax[1][0].set_xlim(PLOTRANGE[0],PLOTRANGE[1])
ax[1][0].set_ylim(PLOTRANGE[2],PLOTRANGE[3])
ax[1][0].set_aspect(0.55/ax[0][0].get_data_ratio())

ax[1][1].set_xlim(PLOTRANGE[0],PLOTRANGE[1])
ax[1][1].set_ylim(PLOTRANGE[2],PLOTRANGE[3])
ax[1][1].set_aspect(0.55/ax[0][0].get_data_ratio())

ax[0][0].plot(dataniki10[:,0],dataniki10[:,1],'-',color=tableau20[0],lw=2, label=r'$x_{CCN}$=0.10')
ax[0][0].plot(dataniki50[:,0],dataniki50[:,1],'-',color=tableau20[1],lw=2, label=r'$x_{CCN}$=0.50')
ax[0][0].plot(dataniki90[:,0],dataniki90[:,1],'-',color=tableau20[2],lw=2, label=r'$x_{CCN}$=0.90')
ax[0][0].legend(loc='upper right',frameon=True,shadow=False,edgecolor='black',fancybox=False,framealpha=1.0,fontsize=0.65*legendlabelsize)

ax[0][0].text(.90, .25, r'a)', transform=ax[0][0].transAxes, ha="left", va="top",fontsize=axislabelsize)
plt.xticks(np.arange(PLOTRANGE[0]+0.1, PLOTRANGE[1]+0.1, 0.1))


ax[0][1].plot(datagrab10[:,0],datagrab10[:,1],'-',color=tableau20[0],lw=2, label=r'$x_{CCN}$=0.10')
ax[0][1].plot(datagrab50[:,0],datagrab50[:,1],'-',color=tableau20[1],lw=2, label=r'$x_{CCN}$=0.50')
ax[0][1].plot(datagrab90[:,0],datagrab90[:,1],'-',color=tableau20[2],lw=2, label=r'$x_{CCN}$=0.90')
ax[0][1].legend(loc='upper right',frameon=True,shadow=False,edgecolor='black',fancybox=False,framealpha=1.0,fontsize=0.65*legendlabelsize)

ax[0][1].text(.90, .25, r'b)', transform=ax[0][1].transAxes, ha="left", va="top",fontsize=axislabelsize)
plt.xticks(np.arange(PLOTRANGE[0]+0.1, PLOTRANGE[1]+0.1, 0.1))


ax[1][0].plot(datakalu10[:,0],datakalu10[:,1],'-',color=tableau20[0],lw=2, label=r'$x_{CCN}$=0.10')
ax[1][0].plot(datakalu50[:,0],datakalu50[:,1],'-',color=tableau20[1],lw=2, label=r'$x_{CCN}$=0.50')
ax[1][0].plot(datakalu90[:,0],datakalu90[:,1],'-',color=tableau20[2],lw=2, label=r'$x_{CCN}$=0.90')
ax[1][0].legend(loc='upper right',frameon=True,shadow=False,edgecolor='black',fancybox=False,framealpha=1.0,fontsize=0.65*legendlabelsize)

ax[1][0].text(.90, .25, r'c)', transform=ax[1][0].transAxes, ha="left", va="top",fontsize=axislabelsize)
plt.sca(ax[1, 0])
plt.xticks(np.arange(PLOTRANGE[0]+0.1, PLOTRANGE[1]+0.1, 0.1))


ax[1][1].plot(datakows10[:,0],datakows10[:,1],'-',color=tableau20[0],lw=2, label=r'$x_{CCN}$=0.10')
ax[1][1].plot(datakows50[:,0],datakows50[:,1],'-',color=tableau20[1],lw=2, label=r'$x_{CCN}$=0.50')
ax[1][1].plot(datakows90[:,0],datakows90[:,1],'-',color=tableau20[2],lw=2, label=r'$x_{CCN}$=0.90')
ax[1][1].legend(loc='upper right',frameon=True,shadow=False,edgecolor='black',fancybox=False,framealpha=1.0,fontsize=0.65*legendlabelsize)

ax[1][1].text(.90, .25, r'd)', transform=ax[1][1].transAxes, ha="left", va="top",fontsize=axislabelsize)
plt.sca(ax[1, 1])
plt.xticks(np.arange(PLOTRANGE[0]+0.1, PLOTRANGE[1]+0.1, 0.1))



ax[0][0].set_ylabel(r'g(r)', fontsize=axislabelsize) # Y label
ax[1][0].set_ylabel(r'g(r)', fontsize=axislabelsize) # Y label
ax[1][0].set_xlabel(r'$r_{\rm}$ [nm]', fontsize=axislabelsize) # X label
ax[1][1].set_xlabel(r'$r_{\rm}$ [nm]', fontsize=axislabelsize) # X label


fig.suptitle('$N-O_{W}$', fontsize=16)
plt.tight_layout()
plt.savefig("rdf_n_ow.png",bbox_inches='tight',dpi=600)

# %%
dataniki10=np.loadtxt("/localscratch/asourpis/metadata_MOGON/ff_evalution/niki/10/rdf_n1_hw.xvg")
dataniki50=np.loadtxt("/localscratch/asourpis/metadata_MOGON/ff_evalution/niki/50/rdf_n1_hw.xvg")
dataniki90=np.loadtxt("/localscratch/asourpis/metadata_MOGON/ff_evalution/niki/90/rdf_n1_hw.xvg")

datakows10=np.loadtxt("/localscratch/asourpis/metadata_MOGON/ff_evalution/kows/10/rdf_n1_hw.xvg")
datakows50=np.loadtxt("/localscratch/asourpis/metadata_MOGON/ff_evalution/kows/50/rdf_n1_hw.xvg")
datakows90=np.loadtxt("/localscratch/asourpis/metadata_MOGON/ff_evalution/kows/90/rdf_n1_hw.xvg")

datagrab10=np.loadtxt("/localscratch/asourpis/metadata_MOGON/ff_evalution/grab/10/rdf_n1_hw.xvg")
datagrab50=np.loadtxt("/localscratch/asourpis/metadata_MOGON/ff_evalution/grab/50/rdf_n1_hw.xvg")
datagrab90=np.loadtxt("/localscratch/asourpis/metadata_MOGON/ff_evalution/grab/90/rdf_n1_hw.xvg")

datakalu10=np.loadtxt("/localscratch/asourpis/metadata_MOGON/ff_evalution/kalu/10/rdf_n1_hw.xvg")
datakalu50=np.loadtxt("/localscratch/asourpis/metadata_MOGON/ff_evalution/kalu/50/rdf_n1_hw.xvg")
datakalu90=np.loadtxt("/localscratch/asourpis/metadata_MOGON/ff_evalution/kalu/90/rdf_n1_hw.xvg")

# %%
fig, ax = plt.subplots(2, 2, sharex='col', sharey='row')

PLOTRANGE = (0.15,0.6,0,3.0)
x = np.linspace(PLOTRANGE[0],PLOTRANGE[1],1000)

ax[0][0].get_yaxis().set_tick_params(which='both', direction='in')
ax[0][0].get_xaxis().set_tick_params(which='both', direction='in')
ax[0][0].yaxis.set_ticks_position('both')
ax[0][0].xaxis.set_ticks_position('both')
ax[0][0].xaxis.set_tick_params(labelsize=ticklabelsize)
ax[0][0].yaxis.set_tick_params(labelsize=ticklabelsize)

#ax[0][1]=plt.gca()
ax[0][1].get_yaxis().set_tick_params(which='both', direction='in')
ax[0][1].get_xaxis().set_tick_params(which='both', direction='in')
ax[0][1].yaxis.set_ticks_position('both')
ax[0][1].xaxis.set_ticks_position('both')
ax[0][1].xaxis.set_tick_params(labelsize=ticklabelsize)
ax[0][1].yaxis.set_tick_params(labelsize=ticklabelsize)

#ax[1][0]=plt.gca()
ax[1][0].get_yaxis().set_tick_params(which='both', direction='in')
ax[1][0].get_xaxis().set_tick_params(which='both', direction='in')
ax[1][0].yaxis.set_ticks_position('both')
ax[1][0].xaxis.set_ticks_position('both')
ax[1][0].xaxis.set_tick_params(labelsize=ticklabelsize)
ax[1][0].yaxis.set_tick_params(labelsize=ticklabelsize)

#ax[1][1]=plt.gca()
ax[1][1].get_yaxis().set_tick_params(which='both', direction='in')
ax[1][1].get_xaxis().set_tick_params(which='both', direction='in')
ax[1][1].yaxis.set_ticks_position('both')
ax[1][1].xaxis.set_ticks_position('both')
ax[1][1].xaxis.set_tick_params(labelsize=ticklabelsize)
ax[1][1].yaxis.set_tick_params(labelsize=ticklabelsize)

ax[0][0].set_xlim(PLOTRANGE[0],PLOTRANGE[1])
ax[0][0].set_ylim(PLOTRANGE[2],PLOTRANGE[3])
ax[0][0].set_aspect(0.55/ax[0][0].get_data_ratio())

ax[0][1].set_xlim(PLOTRANGE[0],PLOTRANGE[1])
ax[0][1].set_ylim(PLOTRANGE[2],PLOTRANGE[3])
ax[0][1].set_aspect(0.55/ax[0][0].get_data_ratio())

ax[1][0].set_xlim(PLOTRANGE[0],PLOTRANGE[1])
ax[1][0].set_ylim(PLOTRANGE[2],PLOTRANGE[3])
ax[1][0].set_aspect(0.55/ax[0][0].get_data_ratio())

ax[1][1].set_xlim(PLOTRANGE[0],PLOTRANGE[1])
ax[1][1].set_ylim(PLOTRANGE[2],PLOTRANGE[3])
ax[1][1].set_aspect(0.55/ax[0][0].get_data_ratio())

ax[0][0].plot(dataniki10[:,0],dataniki10[:,1],'-',color=tableau20[0],lw=2, label=r'$x_{CCN}$=0.10')
ax[0][0].plot(dataniki50[:,0],dataniki50[:,1],'-',color=tableau20[1],lw=2, label=r'$x_{CCN}$=0.50')
ax[0][0].plot(dataniki90[:,0],dataniki90[:,1],'-',color=tableau20[2],lw=2, label=r'$x_{CCN}$=0.90')
ax[0][0].legend(loc='upper right',frameon=True,shadow=False,edgecolor='black',fancybox=False,framealpha=1.0,fontsize=0.65*legendlabelsize)

ax[0][0].text(.90, .25, r'a)', transform=ax[0][0].transAxes, ha="left", va="top",fontsize=axislabelsize)
plt.xticks(np.arange(PLOTRANGE[0]+0.1, PLOTRANGE[1]+0.1, 0.1))


ax[0][1].plot(datagrab10[:,0],datagrab10[:,1],'-',color=tableau20[0],lw=2, label=r'$x_{CCN}$=0.10')
ax[0][1].plot(datagrab50[:,0],datagrab50[:,1],'-',color=tableau20[1],lw=2, label=r'$x_{CCN}$=0.50')
ax[0][1].plot(datagrab90[:,0],datagrab90[:,1],'-',color=tableau20[2],lw=2, label=r'$x_{CCN}$=0.90')
ax[0][1].legend(loc='upper right',frameon=True,shadow=False,edgecolor='black',fancybox=False,framealpha=1.0,fontsize=0.65*legendlabelsize)

ax[0][1].text(.90, .25, r'b)', transform=ax[0][1].transAxes, ha="left", va="top",fontsize=axislabelsize)
plt.xticks(np.arange(PLOTRANGE[0]+0.1, PLOTRANGE[1]+0.1, 0.1))


ax[1][0].plot(datakalu10[:,0],datakalu10[:,1],'-',color=tableau20[0],lw=2, label=r'$x_{CCN}$=0.10')
ax[1][0].plot(datakalu50[:,0],datakalu50[:,1],'-',color=tableau20[1],lw=2, label=r'$x_{CCN}$=0.50')
ax[1][0].plot(datakalu90[:,0],datakalu90[:,1],'-',color=tableau20[2],lw=2, label=r'$x_{CCN}$=0.90')
ax[1][0].legend(loc='upper right',frameon=True,shadow=False,edgecolor='black',fancybox=False,framealpha=1.0,fontsize=0.65*legendlabelsize)

ax[1][0].text(.90, .25, r'c)', transform=ax[1][0].transAxes, ha="left", va="top",fontsize=axislabelsize)
plt.sca(ax[1, 0])
plt.xticks(np.arange(PLOTRANGE[0]+0.1, PLOTRANGE[1]+0.1, 0.1))


ax[1][1].plot(datakows10[:,0],datakows10[:,1],'-',color=tableau20[0],lw=2, label=r'$x_{CCN}$=0.10')
ax[1][1].plot(datakows50[:,0],datakows50[:,1],'-',color=tableau20[1],lw=2, label=r'$x_{CCN}$=0.50')
ax[1][1].plot(datakows90[:,0],datakows90[:,1],'-',color=tableau20[2],lw=2, label=r'$x_{CCN}$=0.90')
ax[1][1].legend(loc='upper right',frameon=True,shadow=False,edgecolor='black',fancybox=False,framealpha=1.0,fontsize=0.65*legendlabelsize)

ax[1][1].text(.90, .25, r'd)', transform=ax[1][1].transAxes, ha="left", va="top",fontsize=axislabelsize)
plt.sca(ax[1, 1])
plt.xticks(np.arange(PLOTRANGE[0]+0.1, PLOTRANGE[1]+0.1, 0.1))



ax[0][0].set_ylabel(r'g(r)', fontsize=axislabelsize) # Y label
ax[1][0].set_ylabel(r'g(r)', fontsize=axislabelsize) # Y label
ax[1][0].set_xlabel(r'$r_{\rm}$ [nm]', fontsize=axislabelsize) # X label
ax[1][1].set_xlabel(r'$r_{\rm}$ [nm]', fontsize=axislabelsize) # X label


fig.suptitle('$N-H_{W}$', fontsize=16)
plt.tight_layout()
plt.savefig("rdf_n_hw.png",bbox_inches='tight',dpi=600)

# %%
ataniki10=np.loadtxt("/localscratch/asourpis/metadata_MOGON/ff_evalution/niki_corr/10/rdf_ow_ow.xvg",comments=['#','@'])
dataniki50=np.loadtxt("/localscratch/asourpis/metadata_MOGON/ff_evalution/niki_corr/50/rdf_ow_ow.xvg",comments=['#','@'])
dataniki90=np.loadtxt("/localscratch/asourpis/metadata_MOGON/ff_evalution/niki_corr/90/rdf_ow_ow.xvg",comments=['#','@'])

datakows10=np.loadtxt("/localscratch/asourpis/metadata_MOGON/ff_evalution/kows/10/rdf_ow_ow.xvg")
datakows50=np.loadtxt("/localscratch/asourpis/metadata_MOGON/ff_evalution/kows/50/rdf_ow_ow.xvg")
datakows90=np.loadtxt("/localscratch/asourpis/metadata_MOGON/ff_evalution/kows/90/rdf_ow_ow.xvg")

datagrab10=np.loadtxt("/localscratch/asourpis/metadata_MOGON/ff_evalution/grab_corr/10/rdf_ow_ow.xvg",comments=['#','@'])
datagrab50=np.loadtxt("/localscratch/asourpis/metadata_MOGON/ff_evalution/grab_corr/50/rdf_ow_ow.xvg",comments=['#','@'])
datagrab90=np.loadtxt("/localscratch/asourpis/metadata_MOGON/ff_evalution/grab_corr/90/rdf_ow_ow.xvg",comments=['#','@'])

datakalu10=np.loadtxt("/localscratch/asourpis/metadata_MOGON/ff_evalution/kalu/10/rdf_ow_ow.xvg")
datakalu50=np.loadtxt("/localscratch/asourpis/metadata_MOGON/ff_evalution/kalu/50/rdf_ow_ow.xvg")
datakalu90=np.loadtxt("/localscratch/asourpis/metadata_MOGON/ff_evalution/kalu/90/rdf_ow_ow.xvg")

# %%
fig, ax = plt.subplots(2, 2, sharex='col', sharey='row')

PLOTRANGE = (0.2,0.7,0,30.0)
x = np.linspace(PLOTRANGE[0],PLOTRANGE[1],1000)

ax[0][0].get_yaxis().set_tick_params(which='both', direction='in')
ax[0][0].get_xaxis().set_tick_params(which='both', direction='in')
ax[0][0].yaxis.set_ticks_position('both')
ax[0][0].xaxis.set_ticks_position('both')
ax[0][0].xaxis.set_tick_params(labelsize=ticklabelsize)
ax[0][0].yaxis.set_tick_params(labelsize=ticklabelsize)

#ax[0][1]=plt.gca()
ax[0][1].get_yaxis().set_tick_params(which='both', direction='in')
ax[0][1].get_xaxis().set_tick_params(which='both', direction='in')
ax[0][1].yaxis.set_ticks_position('both')
ax[0][1].xaxis.set_ticks_position('both')
ax[0][1].xaxis.set_tick_params(labelsize=ticklabelsize)
ax[0][1].yaxis.set_tick_params(labelsize=ticklabelsize)

#ax[1][0]=plt.gca()
ax[1][0].get_yaxis().set_tick_params(which='both', direction='in')
ax[1][0].get_xaxis().set_tick_params(which='both', direction='in')
ax[1][0].yaxis.set_ticks_position('both')
ax[1][0].xaxis.set_ticks_position('both')
ax[1][0].xaxis.set_tick_params(labelsize=ticklabelsize)
ax[1][0].yaxis.set_tick_params(labelsize=ticklabelsize)

#ax[1][1]=plt.gca()
ax[1][1].get_yaxis().set_tick_params(which='both', direction='in')
ax[1][1].get_xaxis().set_tick_params(which='both', direction='in')
ax[1][1].yaxis.set_ticks_position('both')
ax[1][1].xaxis.set_ticks_position('both')
ax[1][1].xaxis.set_tick_params(labelsize=ticklabelsize)
ax[1][1].yaxis.set_tick_params(labelsize=ticklabelsize)

ax[0][0].set_xlim(PLOTRANGE[0],PLOTRANGE[1])
ax[0][0].set_ylim(PLOTRANGE[2],PLOTRANGE[3])
ax[0][0].set_aspect(0.55/ax[0][0].get_data_ratio())

ax[0][1].set_xlim(PLOTRANGE[0],PLOTRANGE[1])
ax[0][1].set_ylim(PLOTRANGE[2],PLOTRANGE[3])
ax[0][1].set_aspect(0.55/ax[0][0].get_data_ratio())

ax[1][0].set_xlim(PLOTRANGE[0],PLOTRANGE[1])
ax[1][0].set_ylim(PLOTRANGE[2],PLOTRANGE[3])
ax[1][0].set_aspect(0.55/ax[0][0].get_data_ratio())

ax[1][1].set_xlim(PLOTRANGE[0],PLOTRANGE[1])
ax[1][1].set_ylim(PLOTRANGE[2],PLOTRANGE[3])
ax[1][1].set_aspect(0.55/ax[0][0].get_data_ratio())

ax[0][0].plot(dataniki10[:,0],dataniki10[:,1],'-',color=tableau20[0],lw=3, label=r'$x_{CCN}$=0.10')
ax[0][0].plot(dataniki50[:,0],dataniki50[:,1],'-',color=tableau20[1],lw=3, label=r'$x_{CCN}$=0.50')
ax[0][0].plot(dataniki90[:,0],dataniki90[:,1],'-',color=tableau20[2],lw=3, label=r'$x_{CCN}$=0.90')
ax[0][0].legend(loc='upper right',frameon=True,shadow=False,edgecolor='black',fancybox=False,framealpha=1.0,fontsize=0.65*legendlabelsize)

ax[0][0].text(.90, .30, r'a)', transform=ax[0][0].transAxes, ha="left", va="top",fontsize=axislabelsize)
plt.xticks(np.arange(PLOTRANGE[0]+0.1, PLOTRANGE[1]+0.1, 0.1))


ax[0][1].plot(datagrab10[:,0],datagrab10[:,1],'-',color=tableau20[0],lw=3, label=r'$x_{CCN}$=0.10')
ax[0][1].plot(datagrab50[:,0],datagrab50[:,1],'-',color=tableau20[1],lw=3, label=r'$x_{CCN}$=0.50')
ax[0][1].plot(datagrab90[:,0],datagrab90[:,1],'-',color=tableau20[2],lw=3, label=r'$x_{CCN}$=0.90')
ax[0][1].legend(loc='upper right',frameon=True,shadow=False,edgecolor='black',fancybox=False,framealpha=1.0,fontsize=0.65*legendlabelsize)

ax[0][1].text(.90, .30, r'b)', transform=ax[0][1].transAxes, ha="left", va="top",fontsize=axislabelsize)
plt.xticks(np.arange(PLOTRANGE[0]+0.1, PLOTRANGE[1]+0.1, 0.1))


ax[1][0].plot(datakalu10[:,0],datakalu10[:,1],'-',color=tableau20[0],lw=3, label=r'$x_{CCN}$=0.10')
ax[1][0].plot(datakalu50[:,0],datakalu50[:,1],'-',color=tableau20[1],lw=3, label=r'$x_{CCN}$=0.50')
ax[1][0].plot(datakalu90[:,0],datakalu90[:,1],'-',color=tableau20[2],lw=3, label=r'$x_{CCN}$=0.90')
ax[1][0].legend(loc='upper right',frameon=True,shadow=False,edgecolor='black',fancybox=False,framealpha=1.0,fontsize=0.65*legendlabelsize)

ax[1][0].text(.90, .30, r'c)', transform=ax[1][0].transAxes, ha="left", va="top",fontsize=axislabelsize)
plt.sca(ax[1, 0])
plt.xticks(np.arange(PLOTRANGE[0]+0.1, PLOTRANGE[1]+0.1, 0.1))


ax[1][1].plot(datakows10[:,0],datakows10[:,1],'-',color=tableau20[0],lw=3, label=r'$x_{CCN}$=0.10')
ax[1][1].plot(datakows50[:,0],datakows50[:,1],'-',color=tableau20[1],lw=3, label=r'$x_{CCN}$=0.50')
ax[1][1].plot(datakows90[:,0],datakows90[:,1],'-',color=tableau20[2],lw=3, label=r'$x_{CCN}$=0.90')
ax[1][1].legend(loc='upper right',frameon=True,shadow=False,edgecolor='black',fancybox=False,framealpha=1.0,fontsize=0.65*legendlabelsize)

ax[1][1].text(.90, .30, r'd)', transform=ax[1][1].transAxes, ha="left", va="top",fontsize=axislabelsize)
plt.sca(ax[1, 1])
plt.xticks(np.arange(PLOTRANGE[0]+0.1, PLOTRANGE[1]+0.1, 0.1))



ax[0][0].set_ylabel(r'g(r)', fontsize=axislabelsize) # Y label
ax[1][0].set_ylabel(r'g(r)', fontsize=axislabelsize) # Y label
ax[1][0].set_xlabel(r'$r_{\rm}$ [nm]', fontsize=axislabelsize) # X label
ax[1][1].set_xlabel(r'$r_{\rm}$ [nm]', fontsize=axislabelsize) # X label


fig.suptitle('$O_{W}-O_{W}$', fontsize=16)
plt.tight_layout()
plt.savefig("corr_si_rdf_ow_ow_10_90.png",bbox_inches='tight',dpi=600)

# %%
dataniki10=np.loadtxt("/localscratch/asourpis/metadata_MOGON/ff_evalution/niki/10/rdf_ow_h.xvg")
dataniki50=np.loadtxt("/localscratch/asourpis/metadata_MOGON/ff_evalution/niki/50/rdf_ow_h.xvg")
dataniki90=np.loadtxt("/localscratch/asourpis/metadata_MOGON/ff_evalution/niki/90/rdf_ow_h.xvg")

datakows10=np.loadtxt("/localscratch/asourpis/metadata_MOGON/ff_evalution/kows/10/rdf_ow_h.xvg")
datakows50=np.loadtxt("/localscratch/asourpis/metadata_MOGON/ff_evalution/kows/50/rdf_ow_h.xvg")
datakows90=np.loadtxt("/localscratch/asourpis/metadata_MOGON/ff_evalution/kows/90/rdf_ow_h.xvg")

datagrab10=np.loadtxt("/localscratch/asourpis/metadata_MOGON/ff_evalution/grab/10/rdf_ow_h.xvg")
datagrab50=np.loadtxt("/localscratch/asourpis/metadata_MOGON/ff_evalution/grab/50/rdf_ow_h.xvg")
datagrab90=np.loadtxt("/localscratch/asourpis/metadata_MOGON/ff_evalution/grab/90/rdf_ow_h.xvg")

datakalu10=np.loadtxt("/localscratch/asourpis/metadata_MOGON/ff_evalution/kalu/10/rdf_ow_h.xvg")
datakalu50=np.loadtxt("/localscratch/asourpis/metadata_MOGON/ff_evalution/kalu/50/rdf_ow_h.xvg")
datakalu90=np.loadtxt("/localscratch/asourpis/metadata_MOGON/ff_evalution/kalu/90/rdf_ow_h.xvg")

# %%
ab_ho_10=np.loadtxt('abrdf_0.109_ho.csv',delimiter=',',skiprows=1)
ab_ho_50=np.loadtxt('abrdf_0.5_ho.csv',delimiter=',',skiprows=1)
ab_ho_90=np.loadtxt('abrdf_0.891_ho.csv',delimiter=',',skiprows=1)

# %%
ab_no_10=np.loadtxt('abrdf_0.109_no.csv',delimiter=',',skiprows=1)
ab_no_50=np.loadtxt('abrdf_0.5_no.csv',delimiter=',',skiprows=1)
ab_no_90=np.loadtxt('abrdf_0.891_no.csv',delimiter=',',skiprows=1)

# %%
ab_nhw_10=np.loadtxt('abrdf_0.109_nhw.csv',delimiter=',',skiprows=1)
ab_nhw_50=np.loadtxt('abrdf_0.5_nhw.csv',delimiter=',',skiprows=1)
ab_nhw_90=np.loadtxt('abrdf_0.891_nhw.csv',delimiter=',',skiprows=1)

# %%
fig, ax = plt.subplots(1, 1, sharex='col', sharey='row')

PLOTRANGE = (0.15,0.55,0,2.0)
x = np.linspace(PLOTRANGE[0],PLOTRANGE[1],1000)

ax.get_yaxis().set_tick_params(which='both', direction='in')
ax.get_xaxis().set_tick_params(which='both', direction='in')
ax.yaxis.set_ticks_position('both')
ax.xaxis.set_ticks_position('both')
ax.xaxis.set_tick_params(labelsize=ticklabelsize)
ax.yaxis.set_tick_params(labelsize=ticklabelsize)

ax.set_xlim(PLOTRANGE[0],PLOTRANGE[1])
ax.set_ylim(PLOTRANGE[2],PLOTRANGE[3])
ax.set_aspect(1/ax.get_data_ratio())

ax.plot(dataniki10[:,0],dataniki10[:,1],'-',color=tableau20[6],lw=2, label=r'$x_{CCN}$=Nikitin')
ax.plot(datagrab10[:,0],datagrab10[:,1],'-',color=tableau20[7],lw=2, label=r'$x_{CCN}$=Grabuleda')
ax.plot(datakalu10[:,0],datakalu10[:,1],'-',color=tableau20[8],lw=2, label=r'$x_{CCN}$=Kalugin')
ax.plot(datakows10[:,0],datakows10[:,1],'-',color=tableau20[9],lw=2, label=r'$x_{CCN}$=Kowsari')
ax.plot(ab_ho_10[:,0]*0.1,ab_ho_10[:,1],'-',color=tableau20[10],lw=2, label=r'$x^{ab-initio}_{CCN}$=0.109')
ax.set_aspect(1/ax.get_data_ratio())

#ax[0][0].plot(dataniki90[:,0],dataniki90[:,1],'-',color=tableau20[2],lw=3, label=r'$x_{CCN}$=0.90')
ax.legend(loc='upper right',frameon=True,shadow=False,edgecolor='black',fancybox=False,framealpha=1.0,fontsize=0.65*legendlabelsize)

#ax.text(.90, .30, r'a)', transform=ax.transAxes, ha="left", va="top",fontsize=axislabelsize)
fig.suptitle('$O-H_{CCN}\;(x_{CCN}=0.10)$', fontsize=16)
plt.xticks(np.arange(PLOTRANGE[0]+0.1, PLOTRANGE[1]+0.1, 0.1))

ax.set_ylabel(r'g(r)', fontsize=axislabelsize) # Y label
ax.set_xlabel(r'$r_{\rm}$ [nm]', fontsize=axislabelsize) # X label

#fig.suptitle('$N-O_{W}$', fontsize=16)
plt.tight_layout()
plt.savefig("ab_cl_rdf_oh_010.png",bbox_inches='tight',dpi=600)

# %%
fig, ax = plt.subplots(1, 1, sharex='col', sharey='row')

PLOTRANGE = (0.15,0.55,0,2.0)
x = np.linspace(PLOTRANGE[0],PLOTRANGE[1],1000)

ax.get_yaxis().set_tick_params(which='both', direction='in')
ax.get_xaxis().set_tick_params(which='both', direction='in')
ax.yaxis.set_ticks_position('both')
ax.xaxis.set_ticks_position('both')
ax.xaxis.set_tick_params(labelsize=ticklabelsize)
ax.yaxis.set_tick_params(labelsize=ticklabelsize)

ax.set_xlim(PLOTRANGE[0],PLOTRANGE[1])
ax.set_ylim(PLOTRANGE[2],PLOTRANGE[3])
ax.set_aspect(1/ax.get_data_ratio())

ax.plot(dataniki50[:,0],dataniki50[:,1],'-',color=tableau20[6],lw=2, label=r'$x_{CCN}$=Nikitin')
ax.plot(datagrab50[:,0],datagrab50[:,1],'-',color=tableau20[7],lw=2, label=r'$x_{CCN}$=Grabuleda')
ax.plot(datakalu50[:,0],datakalu50[:,1],'-',color=tableau20[8],lw=2, label=r'$x_{CCN}$=Kalugin')
ax.plot(datakows50[:,0],datakows50[:,1],'-',color=tableau20[9],lw=2, label=r'$x_{CCN}$=Kowsari')
ax.plot(ab_ho_50[:,0]*0.1,ab_ho_50[:,1],'-',color=tableau20[10],lw=2, label=r'$x^{ab-initio}_{CCN}$=0.5')

ax.set_aspect(1/ax.get_data_ratio())

#ax[0][0].plot(dataniki90[:,0],dataniki90[:,1],'-',color=tableau20[2],lw=3, label=r'$x_{CCN}$=0.90')
ax.legend(loc='upper right',frameon=True,shadow=False,edgecolor='black',fancybox=False,framealpha=1.0,fontsize=0.65*legendlabelsize)

#ax.text(.90, .30, r'a)', transform=ax.transAxes, ha="left", va="top",fontsize=axislabelsize)
fig.suptitle('$O-H_{CCN}\;(x_{CCN}=0.50)$', fontsize=16)
plt.xticks(np.arange(PLOTRANGE[0]+0.1, PLOTRANGE[1]+0.1, 0.1))

ax.set_ylabel(r'g(r)', fontsize=axislabelsize) # Y label
ax.set_xlabel(r'$r_{\rm}$ [nm]', fontsize=axislabelsize) # X label

#fig.suptitle('$N-O_{W}$', fontsize=16)
plt.tight_layout()
plt.savefig("ab_cl_rdf_oh_05.png.png",bbox_inches='tight',dpi=600)

# %%
fig, ax = plt.subplots(1, 1, sharex='col', sharey='row')

PLOTRANGE = (0.15,0.55,0,2.0)
x = np.linspace(PLOTRANGE[0],PLOTRANGE[1],1000)

ax.get_yaxis().set_tick_params(which='both', direction='in')
ax.get_xaxis().set_tick_params(which='both', direction='in')
ax.yaxis.set_ticks_position('both')
ax.xaxis.set_ticks_position('both')
ax.xaxis.set_tick_params(labelsize=ticklabelsize)
ax.yaxis.set_tick_params(labelsize=ticklabelsize)

ax.set_xlim(PLOTRANGE[0],PLOTRANGE[1])
ax.set_ylim(PLOTRANGE[2],PLOTRANGE[3])
ax.set_aspect(1/ax.get_data_ratio())

ax.plot(dataniki90[:,0],dataniki90[:,1],'-',color=tableau20[6],lw=2, label=r'Nikitin')
ax.plot(datagrab90[:,0],datagrab90[:,1],'-',color=tableau20[7],lw=2, label=r'Grabuleda')
ax.plot(datakalu90[:,0],datakalu90[:,1],'-',color=tableau20[8],lw=2, label=r'Kalugin')
ax.plot(datakows90[:,0],datakows90[:,1],'-',color=tableau20[9],lw=2, label=r'Kowsari')
ax.plot(ab_ho_90[:,0]*0.1,ab_ho_90[:,1],'-',color=tableau20[10],lw=2, label=r'$x^{ab-initio}_{CCN}$=0.891')

ax.set_aspect(1/ax.get_data_ratio())

#ax[0][0].plot(dataniki90[:,0],dataniki90[:,1],'-',color=tableau20[2],lw=3, label=r'$x_{CCN}$=0.90')
ax.legend(loc='upper right',frameon=True,shadow=False,edgecolor='black',fancybox=False,framealpha=1.0,fontsize=0.65*legendlabelsize)

#ax.text(.90, .30, r'a)', transform=ax.transAxes, ha="left", va="top",fontsize=axislabelsize)
fig.suptitle('$O-H_{CCN}\;(x_{CCN}=0.90)$', fontsize=16)
plt.xticks(np.arange(PLOTRANGE[0]+0.1, PLOTRANGE[1]+0.1, 0.1))

ax.set_ylabel(r'g(r)', fontsize=axislabelsize) # Y label
ax.set_xlabel(r'$r_{\rm}$ [nm]', fontsize=axislabelsize) # X label

#fig.suptitle('$N-O_{W}$', fontsize=16)
plt.tight_layout()
plt.savefig("ab_cl_rdf_oh_090.png.png",bbox_inches='tight',dpi=600)

# %%
dataniki10=np.loadtxt("/localscratch/asourpis/metadata_MOGON/ff_evalution/niki/10/rdf_n1_hw.xvg")
dataniki50=np.loadtxt("/localscratch/asourpis/metadata_MOGON/ff_evalution/niki/50/rdf_n1_hw.xvg")
dataniki90=np.loadtxt("/localscratch/asourpis/metadata_MOGON/ff_evalution/niki/90/rdf_n1_hw.xvg")

datakows10=np.loadtxt("/localscratch/asourpis/metadata_MOGON/ff_evalution/kows/10/rdf_n1_hw.xvg")
datakows50=np.loadtxt("/localscratch/asourpis/metadata_MOGON/ff_evalution/kows/50/rdf_n1_hw.xvg")
datakows90=np.loadtxt("/localscratch/asourpis/metadata_MOGON/ff_evalution/kows/90/rdf_n1_hw.xvg")

datagrab10=np.loadtxt("/localscratch/asourpis/metadata_MOGON/ff_evalution/grab/10/rdf_n1_hw.xvg")
datagrab50=np.loadtxt("/localscratch/asourpis/metadata_MOGON/ff_evalution/grab/50/rdf_n1_hw.xvg")
datagrab90=np.loadtxt("/localscratch/asourpis/metadata_MOGON/ff_evalution/grab/90/rdf_n1_hw.xvg")

datakalu10=np.loadtxt("/localscratch/asourpis/metadata_MOGON/ff_evalution/kalu/10/rdf_n1_hw.xvg")
datakalu50=np.loadtxt("/localscratch/asourpis/metadata_MOGON/ff_evalution/kalu/50/rdf_n1_hw.xvg")
datakalu90=np.loadtxt("/localscratch/asourpis/metadata_MOGON/ff_evalution/kalu/90/rdf_n1_hw.xvg")

# %%
fig, ax = plt.subplots(1, 1, sharex='col', sharey='row')

PLOTRANGE = (0.15,0.55,0,2.0)
x = np.linspace(PLOTRANGE[0],PLOTRANGE[1],1000)

ax.get_yaxis().set_tick_params(which='both', direction='in')
ax.get_xaxis().set_tick_params(which='both', direction='in')
ax.yaxis.set_ticks_position('both')
ax.xaxis.set_ticks_position('both')
ax.xaxis.set_tick_params(labelsize=ticklabelsize)
ax.yaxis.set_tick_params(labelsize=ticklabelsize)

ax.set_xlim(PLOTRANGE[0],PLOTRANGE[1])
ax.set_ylim(PLOTRANGE[2],PLOTRANGE[3])
ax.set_aspect(1/ax.get_data_ratio())

ax.plot(dataniki10[:,0],dataniki10[:,1],'-',color=tableau20[6],lw=2, label=r'Nikitin')
ax.plot(datagrab10[:,0],datagrab10[:,1],'-',color=tableau20[7],lw=2, label=r'Grabuleda')
ax.plot(datakalu10[:,0],datakalu10[:,1],'-',color=tableau20[8],lw=2, label=r'Koverga')
ax.plot(datakows10[:,0],datakows10[:,1],'-',color=tableau20[9],lw=2, label=r'Kowsari')
ax.plot(ab_nhw_10[:,0]*0.1,ab_nhw_10[:,1],'-',color=tableau20[10],lw=2, label=r'$x^{ab-initio}_{CCN}$=0.109')
ax.set_aspect(1/ax.get_data_ratio())

#ax[0][0].plot(dataniki90[:,0],dataniki90[:,1],'-',color=tableau20[2],lw=3, label=r'$x_{CCN}$=0.90')
ax.legend(loc='upper right',frameon=True,shadow=False,edgecolor='black',fancybox=False,framealpha=1.0,fontsize=0.65*legendlabelsize)

#ax.text(.90, .30, r'a)', transform=ax.transAxes, ha="left", va="top",fontsize=axislabelsize)
fig.suptitle('$N-H_{H_{2}O}\;(x_{CCN}=0.10)$', fontsize=16)
plt.xticks(np.arange(PLOTRANGE[0]+0.1, PLOTRANGE[1]+0.1, 0.1))

ax.set_ylabel(r'g(r)', fontsize=axislabelsize) # Y label
ax.set_xlabel(r'$r_{\rm}$ [nm]', fontsize=axislabelsize) # X label

#fig.suptitle('$N-O_{W}$', fontsize=16)
plt.tight_layout()
plt.savefig("ab_cl_rdf_nhw_010.png",bbox_inches='tight',dpi=600)

# %%
fig, ax = plt.subplots(1, 1, sharex='col', sharey='row')

PLOTRANGE = (0.15,0.55,0,2.0)
x = np.linspace(PLOTRANGE[0],PLOTRANGE[1],1000)

ax.get_yaxis().set_tick_params(which='both', direction='in')
ax.get_xaxis().set_tick_params(which='both', direction='in')
ax.yaxis.set_ticks_position('both')
ax.xaxis.set_ticks_position('both')
ax.xaxis.set_tick_params(labelsize=ticklabelsize)
ax.yaxis.set_tick_params(labelsize=ticklabelsize)

ax.set_xlim(PLOTRANGE[0],PLOTRANGE[1])
ax.set_ylim(PLOTRANGE[2],PLOTRANGE[3])
ax.set_aspect(1/ax.get_data_ratio())

ax.plot(dataniki50[:,0],dataniki50[:,1],'-',color=tableau20[6],lw=2, label=r'Nikitin')
ax.plot(datagrab50[:,0],datagrab50[:,1],'-',color=tableau20[7],lw=2, label=r'Grabuleda')
ax.plot(datakalu50[:,0],datakalu50[:,1],'-',color=tableau20[8],lw=2, label=r'Koverga')
ax.plot(datakows50[:,0],datakows50[:,1],'-',color=tableau20[9],lw=2, label=r'Kowsari')
ax.plot(ab_nhw_50[:,0]*0.1,ab_nhw_50[:,1],'-',color=tableau20[10],lw=2, label=r'$x^{ab-initio}_{CCN}$=0.5')
ax.set_aspect(1/ax.get_data_ratio())

#ax[0][0].plot(dataniki90[:,0],dataniki90[:,1],'-',color=tableau20[2],lw=3, label=r'$x_{CCN}$=0.90')
ax.legend(loc='upper right',frameon=True,shadow=False,edgecolor='black',fancybox=False,framealpha=1.0,fontsize=0.65*legendlabelsize)

#ax.text(.90, .30, r'a)', transform=ax.transAxes, ha="left", va="top",fontsize=axislabelsize)
fig.suptitle('$N-H_{H_{2}O}\;(x_{CCN}=0.50)$', fontsize=16)
plt.xticks(np.arange(PLOTRANGE[0]+0.1, PLOTRANGE[1]+0.1, 0.1))

ax.set_ylabel(r'g(r)', fontsize=axislabelsize) # Y label
ax.set_xlabel(r'$r_{\rm}$ [nm]', fontsize=axislabelsize) # X label

#fig.suptitle('$N-O_{W}$', fontsize=16)
plt.tight_layout()
plt.savefig("ab_cl_rdf_nhw_050.png",bbox_inches='tight',dpi=600)

# %%
fig, ax = plt.subplots(1, 1, sharex='col', sharey='row')

PLOTRANGE = (0.15,0.55,0,3.0)
x = np.linspace(PLOTRANGE[0],PLOTRANGE[1],1000)

ax.get_yaxis().set_tick_params(which='both', direction='in')
ax.get_xaxis().set_tick_params(which='both', direction='in')
ax.yaxis.set_ticks_position('both')
ax.xaxis.set_ticks_position('both')
ax.xaxis.set_tick_params(labelsize=ticklabelsize)
ax.yaxis.set_tick_params(labelsize=ticklabelsize)

ax.set_xlim(PLOTRANGE[0],PLOTRANGE[1])
ax.set_ylim(PLOTRANGE[2],PLOTRANGE[3])
ax.set_aspect(1/ax.get_data_ratio())

ax.plot(dataniki90[:,0],dataniki90[:,1],'-',color=tableau20[6],lw=2, label=r'Nikitin')
ax.plot(datagrab90[:,0],datagrab90[:,1],'-',color=tableau20[7],lw=2, label=r'Grabuleda')
ax.plot(datakalu90[:,0],datakalu90[:,1],'-',color=tableau20[8],lw=2, label=r'Koverga')
ax.plot(datakows90[:,0],datakows90[:,1],'-',color=tableau20[9],lw=2, label=r'Kowsari')
ax.plot(ab_nhw_90[:,0]*0.1,ab_nhw_90[:,1],'-',color=tableau20[10],lw=2, label=r'$x^{ab-initio}_{CCN}$=0.891')
ax.set_aspect(1/ax.get_data_ratio())

#ax[0][0].plot(dataniki90[:,0],dataniki90[:,1],'-',color=tableau20[2],lw=3, label=r'$x_{CCN}$=0.90')
ax.legend(loc='upper right',frameon=True,shadow=False,edgecolor='black',fancybox=False,framealpha=1.0,fontsize=0.65*legendlabelsize)

#ax.text(.90, .30, r'a)', transform=ax.transAxes, ha="left", va="top",fontsize=axislabelsize)
fig.suptitle('$N-H_{H_{2}O}\;(x_{CCN}=0.90)$', fontsize=16)
plt.xticks(np.arange(PLOTRANGE[0]+0.1, PLOTRANGE[1]+0.1, 0.1))

ax.set_ylabel(r'g(r)', fontsize=axislabelsize) # Y label
ax.set_xlabel(r'$r_{\rm}$ [nm]', fontsize=axislabelsize) # X label

#fig.suptitle('$N-O_{W}$', fontsize=16)
plt.tight_layout()
plt.savefig("ab_cl_rdf_nhw_090.png",bbox_inches='tight',dpi=600)

# %%
dataniki10=np.loadtxt("/localscratch/asourpis/metadata_MOGON/ff_evalution/niki/10/rdf_n1_ow.xvg")
dataniki50=np.loadtxt("/localscratch/asourpis/metadata_MOGON/ff_evalution/niki/50/rdf_n1_ow.xvg")
dataniki90=np.loadtxt("/localscratch/asourpis/metadata_MOGON/ff_evalution/niki/90/rdf_n1_ow.xvg")

datakows10=np.loadtxt("/localscratch/asourpis/metadata_MOGON/ff_evalution/kows/10/rdf_n1_ow.xvg")
datakows50=np.loadtxt("/localscratch/asourpis/metadata_MOGON/ff_evalution/kows/50/rdf_n1_ow.xvg")
datakows90=np.loadtxt("/localscratch/asourpis/metadata_MOGON/ff_evalution/kows/90/rdf_n1_ow.xvg")

datagrab10=np.loadtxt("/localscratch/asourpis/metadata_MOGON/ff_evalution/grab/10/rdf_n1_ow.xvg")
datagrab50=np.loadtxt("/localscratch/asourpis/metadata_MOGON/ff_evalution/grab/50/rdf_n1_ow.xvg")
datagrab90=np.loadtxt("/localscratch/asourpis/metadata_MOGON/ff_evalution/grab/90/rdf_n1_ow.xvg")

datakalu10=np.loadtxt("/localscratch/asourpis/metadata_MOGON/ff_evalution/kalu/10/rdf_n1_ow.xvg")
datakalu50=np.loadtxt("/localscratch/asourpis/metadata_MOGON/ff_evalution/kalu/50/rdf_n1_ow.xvg")
datakalu90=np.loadtxt("/localscratch/asourpis/metadata_MOGON/ff_evalution/kalu/90/rdf_n1_ow.xvg")

# %%
fig, ax = plt.subplots(1, 1, sharex='col', sharey='row')

PLOTRANGE = (0.15,0.55,0,2.0)
x = np.linspace(PLOTRANGE[0],PLOTRANGE[1],1000)

ax.get_yaxis().set_tick_params(which='both', direction='in')
ax.get_xaxis().set_tick_params(which='both', direction='in')
ax.yaxis.set_ticks_position('both')
ax.xaxis.set_ticks_position('both')
ax.xaxis.set_tick_params(labelsize=ticklabelsize)
ax.yaxis.set_tick_params(labelsize=ticklabelsize)

ax.set_xlim(PLOTRANGE[0],PLOTRANGE[1])
ax.set_ylim(PLOTRANGE[2],PLOTRANGE[3])
ax.set_aspect(1/ax.get_data_ratio())

ax.plot(dataniki10[:,0],dataniki10[:,1],'-',color=tableau20[6],lw=2, label=r'Nikitin')
ax.plot(datagrab10[:,0],datagrab10[:,1],'-',color=tableau20[7],lw=2, label=r'Grabuleda')
ax.plot(datakalu10[:,0],datakalu10[:,1],'-',color=tableau20[8],lw=2, label=r'Kalugin')
ax.plot(datakows10[:,0],datakows10[:,1],'-',color=tableau20[9],lw=2, label=r'Kowsari')
ax.plot(ab_no_10[:,0]*0.1,ab_no_10[:,1],'-',color=tableau20[10],lw=2, label=r'$x^{ab-initio}_{CCN}$=0.109')
ax.set_aspect(1/ax.get_data_ratio())

#ax[0][0].plot(dataniki90[:,0],dataniki90[:,1],'-',color=tableau20[2],lw=3, label=r'$x_{CCN}$=0.90')
ax.legend(loc='upper right',frameon=True,shadow=False,edgecolor='black',fancybox=False,framealpha=1.0,fontsize=0.65*legendlabelsize)

#ax.text(.90, .30, r'a)', transform=ax.transAxes, ha="left", va="top",fontsize=axislabelsize)
fig.suptitle('$N-O\;(x_{CCN}=0.10)$', fontsize=16)
plt.xticks(np.arange(PLOTRANGE[0]+0.1, PLOTRANGE[1]+0.1, 0.1))

ax.set_ylabel(r'g(r)', fontsize=axislabelsize) # Y label
ax.set_xlabel(r'$r_{\rm}$ [nm]', fontsize=axislabelsize) # X label

#fig.suptitle('$N-O_{W}$', fontsize=16)
plt.tight_layout()
plt.savefig("ab_cl_rdf_no_010.png",bbox_inches='tight',dpi=600)

# %%
fig, ax = plt.subplots(1, 1, sharex='col', sharey='row')

PLOTRANGE = (0.15,0.55,0,2.0)
x = np.linspace(PLOTRANGE[0],PLOTRANGE[1],1000)

ax.get_yaxis().set_tick_params(which='both', direction='in')
ax.get_xaxis().set_tick_params(which='both', direction='in')
ax.yaxis.set_ticks_position('both')
ax.xaxis.set_ticks_position('both')
ax.xaxis.set_tick_params(labelsize=ticklabelsize)
ax.yaxis.set_tick_params(labelsize=ticklabelsize)

ax.set_xlim(PLOTRANGE[0],PLOTRANGE[1])
ax.set_ylim(PLOTRANGE[2],PLOTRANGE[3])
ax.set_aspect(1/ax.get_data_ratio())

ax.plot(dataniki50[:,0],dataniki50[:,1],'-',color=tableau20[6],lw=2, label=r'Nikitin')
ax.plot(datagrab50[:,0],datagrab50[:,1],'-',color=tableau20[7],lw=2, label=r'Grabuleda')
ax.plot(datakalu50[:,0],datakalu50[:,1],'-',color=tableau20[8],lw=2, label=r'Kalugin')
ax.plot(datakows50[:,0],datakows50[:,1],'-',color=tableau20[9],lw=2, label=r'Kowsari')
ax.plot(ab_no_50[:,0]*0.1,ab_no_50[:,1],'-',color=tableau20[10],lw=2, label=r'$x^{ab-initio}_{CCN}$=0.5')
ax.set_aspect(1/ax.get_data_ratio())

#ax[0][0].plot(dataniki90[:,0],dataniki90[:,1],'-',color=tableau20[2],lw=3, label=r'$x_{CCN}$=0.90')
ax.legend(loc='upper right',frameon=True,shadow=False,edgecolor='black',fancybox=False,framealpha=1.0,fontsize=0.65*legendlabelsize)

#ax.text(.90, .30, r'a)', transform=ax.transAxes, ha="left", va="top",fontsize=axislabelsize)
fig.suptitle('$N-O\;(x_{CCN}=0.50)$', fontsize=16)
plt.xticks(np.arange(PLOTRANGE[0]+0.1, PLOTRANGE[1]+0.1, 0.1))

ax.set_ylabel(r'g(r)', fontsize=axislabelsize) # Y label
ax.set_xlabel(r'$r_{\rm}$ [nm]', fontsize=axislabelsize) # X label

#fig.suptitle('$N-O_{W}$', fontsize=16)
plt.tight_layout()
plt.savefig("ab_cl_rdf_no_050.png",bbox_inches='tight',dpi=600)

# %%
fig, ax = plt.subplots(1, 1, sharex='col', sharey='row')

PLOTRANGE = (0.15,0.55,0,3.0)
x = np.linspace(PLOTRANGE[0],PLOTRANGE[1],1000)

ax.get_yaxis().set_tick_params(which='both', direction='in')
ax.get_xaxis().set_tick_params(which='both', direction='in')
ax.yaxis.set_ticks_position('both')
ax.xaxis.set_ticks_position('both')
ax.xaxis.set_tick_params(labelsize=ticklabelsize)
ax.yaxis.set_tick_params(labelsize=ticklabelsize)

ax.set_xlim(PLOTRANGE[0],PLOTRANGE[1])
ax.set_ylim(PLOTRANGE[2],PLOTRANGE[3])
ax.set_aspect(1/ax.get_data_ratio())

ax.plot(dataniki90[:,0],dataniki90[:,1],'-',color=tableau20[6],lw=2, label=r'Nikitin')
ax.plot(datagrab90[:,0],datagrab90[:,1],'-',color=tableau20[7],lw=2, label=r'Grabuleda')
ax.plot(datakalu90[:,0],datakalu90[:,1],'-',color=tableau20[8],lw=2, label=r'Kalugin')
ax.plot(datakows90[:,0],datakows90[:,1],'-',color=tableau20[9],lw=2, label=r'Kowsari')
ax.plot(ab_no_90[:,0]*0.1,ab_no_90[:,1],'-',color=tableau20[10],lw=2, label=r'$x^{ab-initio}_{CCN}$=0.891')
ax.set_aspect(1/ax.get_data_ratio())

#ax[0][0].plot(dataniki90[:,0],dataniki90[:,1],'-',color=tableau20[2],lw=3, label=r'$x_{CCN}$=0.90')
ax.legend(loc='upper right',frameon=True,shadow=False,edgecolor='black',fancybox=False,framealpha=1.0,fontsize=0.65*legendlabelsize)

#ax.text(.90, .30, r'a)', transform=ax.transAxes, ha="left", va="top",fontsize=axislabelsize)
fig.suptitle('$N-O\;(x_{CCN}=0.90)$', fontsize=16)
plt.xticks(np.arange(PLOTRANGE[0]+0.1, PLOTRANGE[1]+0.1, 0.1))

ax.set_ylabel(r'g(r)', fontsize=axislabelsize) # Y label
ax.set_xlabel(r'$r_{\rm}$ [nm]', fontsize=axislabelsize) # X label

#fig.suptitle('$N-O_{W}$', fontsize=16)
plt.tight_layout()
plt.savefig("ab_cl_rdf_no_090.png",bbox_inches='tight',dpi=600)

# %%
fig, ax = plt.subplots(1, 1, sharex='col', sharey='row')

PLOTRANGE = (0.15,0.55,0,2.0)
x = np.linspace(PLOTRANGE[0],PLOTRANGE[1],1000)

ax.get_yaxis().set_tick_params(which='both', direction='in')
ax.get_xaxis().set_tick_params(which='both', direction='in')
ax.yaxis.set_ticks_position('both')
ax.xaxis.set_ticks_position('both')
ax.xaxis.set_tick_params(labelsize=ticklabelsize)
ax.yaxis.set_tick_params(labelsize=ticklabelsize)

ax.set_xlim(PLOTRANGE[0],PLOTRANGE[1])
ax.set_ylim(PLOTRANGE[2],PLOTRANGE[3])
ax.set_aspect(1/ax.get_data_ratio())

ax.plot(dataniki10[:,0],dataniki10[:,1],'-',color=tableau20[6],lw=2, label=r'$x_{CCN}$=Nikitin')
ax.plot(datagrab10[:,0],datagrab10[:,1],'-',color=tableau20[7],lw=2, label=r'$x_{CCN}$=Grabuleda')
ax.plot(datakalu10[:,0],datakalu10[:,1],'-',color=tableau20[8],lw=2, label=r'$x_{CCN}$=Kalugin')
ax.plot(datakows10[:,0],datakows10[:,1],'-',color=tableau20[9],lw=2, label=r'$x_{CCN}$=Kowsari')
ax.plot(ab_ho_10[:,0]*0.1,ab_ho_10[:,1],'-',color=tableau20[10],lw=2, label=r'$x^{ab-initio}_{CCN}$=0.109')
ax.set_aspect(1/ax.get_data_ratio())

#ax[0][0].plot(dataniki90[:,0],dataniki90[:,1],'-',color=tableau20[2],lw=3, label=r'$x_{CCN}$=0.90')
ax.legend(loc='upper right',frameon=True,shadow=False,edgecolor='black',fancybox=False,framealpha=1.0,fontsize=0.65*legendlabelsize)

#ax.text(.90, .30, r'a)', transform=ax.transAxes, ha="left", va="top",fontsize=axislabelsize)
fig.suptitle('$O-H_{CCN}\;(x_{CCN}=0.10)$', fontsize=16)
plt.xticks(np.arange(PLOTRANGE[0]+0.1, PLOTRANGE[1]+0.1, 0.1))

ax.set_ylabel(r'g(r)', fontsize=axislabelsize) # Y label
ax.set_xlabel(r'$r_{\rm}$ [nm]', fontsize=axislabelsize) # X label

#fig.suptitle('$N-O_{W}$', fontsize=16)
plt.tight_layout()
plt.savefig("ab_cl_rdf_oh_010.png",bbox_inches='tight',dpi=600)
# Out:
# array([], shape=(0, 2), dtype=float64)

# %%
fig, ax = plt.subplots(3, 1, sharex='col', sharey='row')

PLOTRANGE = (0.15,0.6,0,1.5)
x = np.linspace(PLOTRANGE[0],PLOTRANGE[1],1000)

ax[0][0].get_yaxis().set_tick_params(which='both', direction='in')
ax[0][0].get_xaxis().set_tick_params(which='both', direction='in')
ax[0][0].yaxis.set_ticks_position('both')
ax[0][0].xaxis.set_ticks_position('both')
ax[0].xaxis.set_tick_params(labelsize=ticklabelsize)
ax[0].yaxis.set_tick_params(labelsize=ticklabelsize)

#ax[0][1]=plt.gca()
ax[1].get_yaxis().set_tick_params(which='both', direction='in')
ax[1].get_xaxis().set_tick_params(which='both', direction='in')
ax[1].yaxis.set_ticks_position('both')
ax[1].xaxis.set_ticks_position('both')
ax[1].xaxis.set_tick_params(labelsize=ticklabelsize)
ax[1].yaxis.set_tick_params(labelsize=ticklabelsize)

#ax[1][0]=plt.gca()
ax[2].get_yaxis().set_tick_params(which='both', direction='in')
ax[2].get_xaxis().set_tick_params(which='both', direction='in')
ax[2].yaxis.set_ticks_position('both')
ax[2].xaxis.set_ticks_position('both')
ax[2].xaxis.set_tick_params(labelsize=ticklabelsize)
ax[2].yaxis.set_tick_params(labelsize=ticklabelsize)


ax[0].plot(dataniki10[:,0],dataniki10[:,1],'-',color=tableau20[6],lw=2, label=r'$x_{CCN}$=0.10')
ax[0].plot(datagrab10[:,0],datagrab10[:,1],'-',color=tableau20[7],lw=2, label=r'$x_{CCN}$=0.10')
ax[0].plot(datakalu10[:,0],datakalu10[:,1],'-',color=tableau20[8],lw=2, label=r'$x_{CCN}$=0.10')
ax[0].plot(datakows10[:,0],datakows10[:,1],'-',color=tableau20[9],lw=2, label=r'$x_{CCN}$=0.10')
ax[0].set_aspect(1/ax[0].get_data_ratio())

#ax[0].plot(ab_ho_10[:,0],ab_ho_10[:,1],'-',color=tableau20[10],lw=2, label=r'$x^{ab-initio}_{CCN}$=0.109')
#ax[0][0].plot(dataniki50[:,0],dataniki50[:,1],'-',color=tableau20[4],lw=2, label=r'$x_{CCN}$=0.50')
#ax[0][0].plot(dataniki90[:,0],dataniki90[:,1],'-',color=tableau20[0],lw=2, label=r'$x_{CCN}$=0.90')
#ax[0].legend(loc='lower right',frameon=True,shadow=False,edgecolor='black',fancybox=False,framealpha=1.0,fontsize=0.65*legendlabelsize)

ax[0].text(.05, .90, r'a)', transform=ax[0].transAxes, ha="left", va="top",fontsize=axislabelsize)
#plt.xticks(np.arange(PLOTRANGE[0]+0.1, PLOTRANGE[1]+0.1, 0.1))


ax[1].plot(dataniki50[:,0],dataniki50[:,1],'-',color=tableau20[6],lw=2, label=r'$x_{CCN}$=0.50')
ax[1].plot(datagrab50[:,0],datagrab50[:,1],'-',color=tableau20[7],lw=2, label=r'$x_{CCN}$=0.50')
ax[1].plot(datakalu50[:,0],datakalu50[:,1],'-',color=tableau20[8],lw=2, label=r'$x_{CCN}$=0.50')
ax[1].plot(datakows50[:,0],datakows50[:,1],'-',color=tableau20[9],lw=2, label=r'$x_{CCN}$=0.50')
ax[1].set_aspect(1/ax[1].get_data_ratio())
#ax[1].plot(ab_ho_50[:,0],ab_ho_50[:,1],'-',color=tableau20[10],lw=2, label=r'$x^{ab-initio}_{CCN}$=0.5')
#ax[0][1].plot(datagrab90[:,0],datagrab90[:,1],'-',color=tableau20[0],lw=2, label=r'$x_{CCN}$=0.90')
#ax[0][1].legend(loc='lower right',frameon=True,shadow=False,edgecolor='black',fancybox=False,framealpha=1.0,fontsize=0.65*legendlabelsize)
#ax[1].text(.05, .90, r'b)', transform=ax[1].transAxes, ha="left", va="top",fontsize=axislabelsize)
#plt.xticks(np.arange(PLOTRANGE[0]+0.1, PLOTRANGE[1]+0.1, 0.1))


ax[2].plot(dataniki90[:,0],dataniki90[:,1],'-',color=tableau20[6],lw=2, label=r'$x_{CCN}$=0.90')
ax[2].plot(datagrab90[:,0],datagrab90[:,1],'-',color=tableau20[7],lw=2, label=r'$x_{CCN}$=0.90')
ax[2].plot(datakalu90[:,0],datakalu90[:,1],'-',color=tableau20[8],lw=2, label=r'$x_{CCN}$=0.90')
ax[2].plot(datakows90[:,0],datakows90[:,1],'-',color=tableau20[9],lw=2, label=r'$x_{CCN}$=0.90')
ax[2].set_aspect(1/ax[2].get_data_ratio())
#ax[2].plot(ab_ho_90[:,0],ab_ho_90[:,1],'-',color=tableau20[10],lw=2, label=r'$x^{ab-initio}_{CCN}$=0.5')

#ax[2].text(.05, .90, r'c)', transform=ax[2].transAxes, ha="left", va="top",fontsize=axislabelsize)
#plt.xticks(np.arange(PLOTRANGE[0]+0.1, PLOTRANGE[1]+0.1, 0.1))

#ax[0].set_ylabel(r'g(r)', fontsize=axislabelsize) # Y label
#ax[1].set_ylabel(r'g(r)', fontsize=axislabelsize) # Y label
#ax[2].set_xlabel(r'$r_{\rm}$ [nm]', fontsize=axislabelsize) # X label


fig.suptitle('$O_{W}-H_{CCN}$', fontsize=16)
plt.xticks(np.arange(PLOTRANGE[0]+0.1, PLOTRANGE[1]+0.1, 0.1))

plt.tight_layout()
#plt.savefig("rdf_ow_hccn.png",bbox_inches='tight',dpi=600)

# %%
x
# Out:
# array([0.15      , 0.15045045, 0.1509009 , 0.15135135, 0.1518018 ,
#        0.15225225, 0.1527027 , 0.15315315, 0.1536036 , 0.15405405,
#        0.1545045 , 0.15495495, 0.15540541, 0.15585586, 0.15630631,
#        0.15675676, 0.15720721, 0.15765766, 0.15810811, 0.15855856,
#        0.15900901, 0.15945946, 0.15990991, 0.16036036, 0.16081081,
#        0.16126126, 0.16171171, 0.16216216, 0.16261261, 0.16306306,
#        0.16351351, 0.16396396, 0.16441441, 0.16486486, 0.16531532,
#        0.16576577, 0.16621622, 0.16666667, 0.16711712, 0.16756757,
#        0.16801802, 0.16846847, 0.16891892, 0.16936937, 0.16981982,
#        0.17027027, 0.17072072, 0.17117117, 0.17162162, 0.17207207,
#        0.17252252, 0.17297297, 0.17342342, 0.17387387, 0.17432432,
#        0.17477477, 0.17522523, 0.17567568, 0.17612613, 0.17657658,
#        0.17702703, 0.17747748, 0.17792793, 0.17837838, 0.17882883,
#        0.17927928, 0.17972973, 0.18018018, 0.18063063, 0.18108108,
# ...

# %%
x=ab_ho_50[:,0]*0.1

# %%
fig, ax = plt.subplots(2, 2, sharex='col', sharey='row')

PLOTRANGE = (0.15,0.6,0,3.0)
x = np.linspace(PLOTRANGE[0],PLOTRANGE[1],1000)

ax[0][0].get_yaxis().set_tick_params(which='both', direction='in')
ax[0][0].get_xaxis().set_tick_params(which='both', direction='in')
ax[0][0].yaxis.set_ticks_position('both')
ax[0][0].xaxis.set_ticks_position('both')
ax[0][0].xaxis.set_tick_params(labelsize=ticklabelsize)
ax[0][0].yaxis.set_tick_params(labelsize=ticklabelsize)

#ax[0][1]=plt.gca()
ax[0][1].get_yaxis().set_tick_params(which='both', direction='in')
ax[0][1].get_xaxis().set_tick_params(which='both', direction='in')
ax[0][1].yaxis.set_ticks_position('both')
ax[0][1].xaxis.set_ticks_position('both')
ax[0][1].xaxis.set_tick_params(labelsize=ticklabelsize)
ax[0][1].yaxis.set_tick_params(labelsize=ticklabelsize)

#ax[1][0]=plt.gca()
ax[1][0].get_yaxis().set_tick_params(which='both', direction='in')
ax[1][0].get_xaxis().set_tick_params(which='both', direction='in')
ax[1][0].yaxis.set_ticks_position('both')
ax[1][0].xaxis.set_ticks_position('both')
ax[1][0].xaxis.set_tick_params(labelsize=ticklabelsize)
ax[1][0].yaxis.set_tick_params(labelsize=ticklabelsize)

#ax[1][1]=plt.gca()
ax[1][1].get_yaxis().set_tick_params(which='both', direction='in')
ax[1][1].get_xaxis().set_tick_params(which='both', direction='in')
ax[1][1].yaxis.set_ticks_position('both')
ax[1][1].xaxis.set_ticks_position('both')
ax[1][1].xaxis.set_tick_params(labelsize=ticklabelsize)
ax[1][1].yaxis.set_tick_params(labelsize=ticklabelsize)

ax[0][0].set_xlim(PLOTRANGE[0],PLOTRANGE[1])
ax[0][0].set_ylim(PLOTRANGE[2],PLOTRANGE[3])
ax[0][0].set_aspect(0.55/ax[0][0].get_data_ratio())

ax[0][1].set_xlim(PLOTRANGE[0],PLOTRANGE[1])
ax[0][1].set_ylim(PLOTRANGE[2],PLOTRANGE[3])
ax[0][1].set_aspect(0.55/ax[0][0].get_data_ratio())

ax[1][0].set_xlim(PLOTRANGE[0],PLOTRANGE[1])
ax[1][0].set_ylim(PLOTRANGE[2],PLOTRANGE[3])
ax[1][0].set_aspect(0.55/ax[0][0].get_data_ratio())

ax[1][1].set_xlim(PLOTRANGE[0],PLOTRANGE[1])
ax[1][1].set_ylim(PLOTRANGE[2],PLOTRANGE[3])
ax[1][1].set_aspect(0.55/ax[0][0].get_data_ratio())

ax[0][0].plot(dataniki10[:,0],dataniki10[:,1],'-',color=tableau20[6],lw=2, label=r'$x_{CCN}$=0.10')
ax[0][0].plot(dataniki50[:,0],dataniki50[:,1],'-',color=tableau20[4],lw=2, label=r'$x_{CCN}$=0.50')
ax[0][0].plot(dataniki90[:,0],dataniki90[:,1],'-',color=tableau20[0],lw=2, label=r'$x_{CCN}$=0.90')
ax[0][0].legend(loc='upper right',frameon=True,shadow=False,edgecolor='black',fancybox=False,framealpha=1.0,fontsize=0.65*legendlabelsize)

ax[0][0].text(.90, .25, r'a)', transform=ax[0][0].transAxes, ha="left", va="top",fontsize=axislabelsize)
plt.xticks(np.arange(PLOTRANGE[0]+0.1, PLOTRANGE[1]+0.1, 0.1))


ax[0][1].plot(datagrab10[:,0],datagrab10[:,1],'-',color=tableau20[6],lw=2, label=r'$x_{CCN}$=0.10')
ax[0][1].plot(datagrab50[:,0],datagrab50[:,1],'-',color=tableau20[4],lw=2, label=r'$x_{CCN}$=0.50')
ax[0][1].plot(datagrab90[:,0],datagrab90[:,1],'-',color=tableau20[0],lw=2, label=r'$x_{CCN}$=0.90')
ax[0][1].legend(loc='upper right',frameon=True,shadow=False,edgecolor='black',fancybox=False,framealpha=1.0,fontsize=0.65*legendlabelsize)

ax[0][1].text(.90, .25, r'b)', transform=ax[0][1].transAxes, ha="left", va="top",fontsize=axislabelsize)
plt.xticks(np.arange(PLOTRANGE[0]+0.1, PLOTRANGE[1]+0.1, 0.1))


ax[1][0].plot(datakalu10[:,0],datakalu10[:,1],'-',color=tableau20[6],lw=2, label=r'$x_{CCN}$=0.10')
ax[1][0].plot(datakalu50[:,0],datakalu50[:,1],'-',color=tableau20[4],lw=2, label=r'$x_{CCN}$=0.50')
ax[1][0].plot(datakalu90[:,0],datakalu90[:,1],'-',color=tableau20[0],lw=2, label=r'$x_{CCN}$=0.90')
ax[1][0].legend(loc='upper right',frameon=True,shadow=False,edgecolor='black',fancybox=False,framealpha=1.0,fontsize=0.65*legendlabelsize)

ax[1][0].text(.90, .25, r'c)', transform=ax[1][0].transAxes, ha="left", va="top",fontsize=axislabelsize)
plt.sca(ax[1, 0])
plt.xticks(np.arange(PLOTRANGE[0]+0.1, PLOTRANGE[1]+0.1, 0.1))


ax[1][1].plot(datakows10[:,0],datakows10[:,1],'-',color=tableau20[6],lw=2, label=r'$x_{CCN}$=0.10')
ax[1][1].plot(datakows50[:,0],datakows50[:,1],'-',color=tableau20[4],lw=2, label=r'$x_{CCN}$=0.50')
ax[1][1].plot(datakows90[:,0],datakows90[:,1],'-',color=tableau20[0],lw=2, label=r'$x_{CCN}$=0.90')
ax[1][1].legend(loc='upper right',frameon=True,shadow=False,edgecolor='black',fancybox=False,framealpha=1.0,fontsize=0.65*legendlabelsize)

ax[1][1].text(.90, .25, r'd)', transform=ax[1][1].transAxes, ha="left", va="top",fontsize=axislabelsize)
plt.sca(ax[1, 1])
plt.xticks(np.arange(PLOTRANGE[0]+0.1, PLOTRANGE[1]+0.1, 0.1))



ax[0][0].set_ylabel(r'g(r)', fontsize=axislabelsize) # Y label
ax[1][0].set_ylabel(r'g(r)', fontsize=axislabelsize) # Y label
ax[1][0].set_xlabel(r'$r_{\rm}$ [nm]', fontsize=axislabelsize) # X label
ax[1][1].set_xlabel(r'$r_{\rm}$ [nm]', fontsize=axislabelsize) # X label


fig.suptitle('$N-H_{W}$', fontsize=16)
plt.tight_layout()
plt.savefig("rdf_n_hw.png",bbox_inches='tight',dpi=600)

# %%
rdf001n1ow=np.loadtxt("/localscratch/asourpis/metadata_MOGON/rdfs_linear/0.01/rdf_n1_ow.xvg",comments={'@','#'})
rdf002n1ow=np.loadtxt("/localscratch/asourpis/metadata_MOGON/rdfs_linear/0.02/rdf_n1_ow.xvg",comments={'@','#'})
rdf003n1ow=np.loadtxt("/localscratch/asourpis/metadata_MOGON/rdfs_linear/0.03/rdf_n1_ow.xvg",comments={'@','#'})
rdf004n1ow=np.loadtxt("/localscratch/asourpis/metadata_MOGON/rdfs_linear/0.04/rdf_n1_ow.xvg",comments={'@','#'})
rdf005n1ow=np.loadtxt("/localscratch/asourpis/metadata_MOGON/rdfs_linear/0.05/rdf_n1_ow.xvg",comments={'@','#'})
rdf006n1ow=np.loadtxt("/localscratch/asourpis/metadata_MOGON/rdfs_linear/0.06/rdf_n1_ow.xvg",comments={'@','#'})
rdf007n1ow=np.loadtxt("/localscratch/asourpis/metadata_MOGON/rdfs_linear/0.07/rdf_n1_ow.xvg",comments={'@','#'})
rdf008n1ow=np.loadtxt("/localscratch/asourpis/metadata_MOGON/rdfs_linear/0.08/rdf_n1_ow.xvg",comments={'@','#'})
rdf009n1ow=np.loadtxt("/localscratch/asourpis/metadata_MOGON/rdfs_linear/0.09/rdf_n1_ow.xvg",comments={'@','#'})

# %%
fig, ax = plt.subplots(1, 1, sharex='col', sharey='row')

PLOTRANGE = (0.15,0.7,0,2.0)
x = np.linspace(PLOTRANGE[0],PLOTRANGE[1],1000)

ax.get_yaxis().set_tick_params(which='both', direction='in')
ax.get_xaxis().set_tick_params(which='both', direction='in')
ax.yaxis.set_ticks_position('both')
ax.xaxis.set_ticks_position('both')
ax.xaxis.set_tick_params(labelsize=ticklabelsize)
ax.yaxis.set_tick_params(labelsize=ticklabelsize)

ax.set_xlim(PLOTRANGE[0],PLOTRANGE[1])
ax.set_ylim(PLOTRANGE[2],PLOTRANGE[3])
ax.set_aspect(1/ax.get_data_ratio())

ax.plot(rdf001n1ow[:,0],rdf001n1ow[:,1],'-',color=tableau20[0],lw=3, label=r'$E$=0.01')
ax.plot(rdf002n1ow[:,0],rdf002n1ow[:,1],'-',color=tableau20[1],lw=3, label=r'$E$=0.02')
ax.plot(rdf003n1ow[:,0],rdf003n1ow[:,1],'-',color=tableau20[2],lw=3, label=r'$E$=0.03')
ax.plot(rdf004n1ow[:,0],rdf004n1ow[:,1],'-',color=tableau20[3],lw=3, label=r'$E$=0.04')
ax.plot(rdf005n1ow[:,0],rdf005n1ow[:,1],'-',color=tableau20[5],lw=3, label=r'$E$=0.05')
ax.plot(rdf006n1ow[:,0],rdf006n1ow[:,1],'-',color=tableau20[7],lw=3, label=r'$E$=0.06')
ax.plot(rdf007n1ow[:,0],rdf007n1ow[:,1],'-',color=tableau20[9],lw=3, label=r'$E$=0.07')
ax.plot(rdf008n1ow[:,0],rdf008n1ow[:,1],'-',color=tableau20[10],lw=3, label=r'$E$=0.08')
ax.plot(rdf009n1ow[:,0],rdf009n1ow[:,1],'-',color=tableau20[12],lw=3, label=r'$E$=0.09')

#ax[0][0].plot(dataniki90[:,0],dataniki90[:,1],'-',color=tableau20[2],lw=3, label=r'$x_{CCN}$=0.90')
ax.legend(loc='upper right',frameon=True,shadow=False,edgecolor='black',fancybox=False,framealpha=1.0,fontsize=0.65*legendlabelsize)

#ax.text(.90, .30, r'a)', transform=ax.transAxes, ha="left", va="top",fontsize=axislabelsize)
plt.xticks(np.arange(PLOTRANGE[0]+0.1, PLOTRANGE[1]+0.1, 0.1))

ax.set_ylabel(r'g(r)', fontsize=axislabelsize) # Y label
ax.set_xlabel(r'$r_{\rm}$ [nm]', fontsize=axislabelsize) # X label

fig.suptitle('$N-O_{W}$', fontsize=16)
plt.tight_layout()
plt.savefig("rdf_n_ow_lnr_regime.png",bbox_inches='tight',dpi=600)

# %%
rdf001n1hw=np.loadtxt("/localscratch/asourpis/metadata_MOGON/rdfs_linear/0.01/rdf_n1_hw.xvg",comments={'@','#'})
rdf002n1hw=np.loadtxt("/localscratch/asourpis/metadata_MOGON/rdfs_linear/0.02/rdf_n1_hw.xvg",comments={'@','#'})
rdf003n1hw=np.loadtxt("/localscratch/asourpis/metadata_MOGON/rdfs_linear/0.03/rdf_n1_hw.xvg",comments={'@','#'})
rdf004n1hw=np.loadtxt("/localscratch/asourpis/metadata_MOGON/rdfs_linear/0.04/rdf_n1_hw.xvg",comments={'@','#'})
rdf005n1hw=np.loadtxt("/localscratch/asourpis/metadata_MOGON/rdfs_linear/0.05/rdf_n1_hw.xvg",comments={'@','#'})
rdf006n1hw=np.loadtxt("/localscratch/asourpis/metadata_MOGON/rdfs_linear/0.06/rdf_n1_hw.xvg",comments={'@','#'})
rdf007n1hw=np.loadtxt("/localscratch/asourpis/metadata_MOGON/rdfs_linear/0.07/rdf_n1_hw.xvg",comments={'@','#'})
rdf008n1hw=np.loadtxt("/localscratch/asourpis/metadata_MOGON/rdfs_linear/0.08/rdf_n1_hw.xvg",comments={'@','#'})
rdf009n1hw=np.loadtxt("/localscratch/asourpis/metadata_MOGON/rdfs_linear/0.09/rdf_n1_hw.xvg",comments={'@','#'})

# %%
fig, ax = plt.subplots(1, 1, sharex='col', sharey='row')

PLOTRANGE = (0.15,0.7,0,2.0)
x = np.linspace(PLOTRANGE[0],PLOTRANGE[1],1000)

ax.get_yaxis().set_tick_params(which='both', direction='in')
ax.get_xaxis().set_tick_params(which='both', direction='in')
ax.yaxis.set_ticks_position('both')
ax.xaxis.set_ticks_position('both')
ax.xaxis.set_tick_params(labelsize=ticklabelsize)
ax.yaxis.set_tick_params(labelsize=ticklabelsize)

ax.set_xlim(PLOTRANGE[0],PLOTRANGE[1])
ax.set_ylim(PLOTRANGE[2],PLOTRANGE[3])
ax.set_aspect(1/ax.get_data_ratio())

ax.plot(rdf001n1hw[:,0],rdf001n1hw[:,1],'-',color=tableau20[0],lw=3, label=r'$E$=0.01')
ax.plot(rdf002n1hw[:,0],rdf002n1hw[:,1],'-',color=tableau20[1],lw=3, label=r'$E$=0.02')
ax.plot(rdf003n1hw[:,0],rdf003n1hw[:,1],'-',color=tableau20[2],lw=3, label=r'$E$=0.03')
ax.plot(rdf004n1hw[:,0],rdf004n1hw[:,1],'-',color=tableau20[3],lw=3, label=r'$E$=0.04')
ax.plot(rdf005n1hw[:,0],rdf005n1hw[:,1],'-',color=tableau20[5],lw=3, label=r'$E$=0.05')
ax.plot(rdf006n1hw[:,0],rdf006n1hw[:,1],'-',color=tableau20[7],lw=3, label=r'$E$=0.06')
ax.plot(rdf007n1hw[:,0],rdf007n1hw[:,1],'-',color=tableau20[9],lw=3, label=r'$E$=0.07')
ax.plot(rdf008n1hw[:,0],rdf008n1hw[:,1],'-',color=tableau20[10],lw=3, label=r'$E$=0.08')
ax.plot(rdf009n1hw[:,0],rdf009n1hw[:,1],'-',color=tableau20[12],lw=3, label=r'$E$=0.09')

#ax[0][0].plot(dataniki90[:,0],dataniki90[:,1],'-',color=tableau20[2],lw=3, label=r'$x_{CCN}$=0.90')
ax.legend(loc='upper right',frameon=True,shadow=False,edgecolor='black',fancybox=False,framealpha=1.0,fontsize=0.65*legendlabelsize)

#ax.text(.90, .30, r'a)', transform=ax.transAxes, ha="left", va="top",fontsize=axislabelsize)
plt.xticks(np.arange(PLOTRANGE[0]+0.1, PLOTRANGE[1]+0.1, 0.1))

ax.set_ylabel(r'g(r)', fontsize=axislabelsize) # Y label
ax.set_xlabel(r'$r_{\rm}$ [nm]', fontsize=axislabelsize) # X label

fig.suptitle('$N-H_{W}$', fontsize=16)
plt.tight_layout()
plt.savefig("rdf_n_hw_lnr_regime.png",bbox_inches='tight',dpi=600)

# %%
rdfab0109nhw=np.loadtxt('/localscratch/asourpis/metadata_MOGON/ff_evalution/ab-initio/rdfaiNHw0.109.dat')
rdfab05nhw=np.loadtxt('/localscratch/asourpis/metadata_MOGON/ff_evalution/ab-initio/rdfaiNHw0.5.dat')
rdfab0891nhw=np.loadtxt('/localscratch/asourpis/metadata_MOGON/ff_evalution/ab-initio/rdfaiNHw0.891.dat')

# %%
fig, ax = plt.subplots(1, 1, sharex='col', sharey='row')

PLOTRANGE = (0.15,0.7,0,2.0)
x = np.linspace(PLOTRANGE[0],PLOTRANGE[1],1000)

ax.get_yaxis().set_tick_params(which='both', direction='in')
ax.get_xaxis().set_tick_params(which='both', direction='in')
ax.yaxis.set_ticks_position('both')
ax.xaxis.set_ticks_position('both')
ax.xaxis.set_tick_params(labelsize=ticklabelsize)
ax.yaxis.set_tick_params(labelsize=ticklabelsize)

ax.set_xlim(PLOTRANGE[0],PLOTRANGE[1])
ax.set_ylim(PLOTRANGE[2],PLOTRANGE[3])
ax.set_aspect(1/ax.get_data_ratio())

ax.plot(rdfab0109nhw[:,0]*0.1,rdfab0109nhw[:,1],'-',color=tableau20[6],lw=2, label=r'$x_{CCN}$=0.109')
ax.plot(rdfab05nhw[:,0]*0.1,rdfab05nhw[:,1],'-',color=tableau20[4],lw=2, label=r'$x_{CCN}$=0.5')
ax.plot(rdfab0891nhw[:,0]*0.1,rdfab0891nhw[:,1],'-',color=tableau20[0],lw=2, label=r'$x_{CCN}$=0.891')

#ax[0][0].plot(dataniki90[:,0],dataniki90[:,1],'-',color=tableau20[2],lw=3, label=r'$x_{CCN}$=0.90')
ax.legend(loc='upper right',frameon=True,shadow=False,edgecolor='black',fancybox=False,framealpha=1.0,fontsize=0.65*legendlabelsize)

#ax.text(.90, .30, r'a)', transform=ax.transAxes, ha="left", va="top",fontsize=axislabelsize)
plt.xticks(np.arange(PLOTRANGE[0]+0.1, PLOTRANGE[1]+0.1, 0.1))

ax.set_ylabel(r'g(r)', fontsize=axislabelsize) # Y label
ax.set_xlabel(r'$r_{\rm}$ [nm]', fontsize=axislabelsize) # X label

fig.suptitle('$N-H_{W}$', fontsize=16)
plt.tight_layout()
#plt.savefig("ab-initio_rdf_n_hw.png",bbox_inches='tight',dpi=600)

# %%
rdfab0109nhw[:,0]*0.1
# Out:
# array([0.14765 , 0.152997, 0.155673, 0.157458, 0.160142, 0.162823,
#        0.16373 , 0.165527, 0.169099, 0.168221, 0.170015, 0.170919,
#        0.170944, 0.173625, 0.173638, 0.175432, 0.176342, 0.178136,
#        0.179927, 0.184389, 0.18618 , 0.189746, 0.19687 , 0.198646,
#        0.202186, 0.205729, 0.206608, 0.210155, 0.211921, 0.213695,
#        0.216355, 0.217234, 0.219005, 0.219887, 0.225216, 0.226096,
#        0.231424, 0.23408 , 0.236737, 0.240284, 0.243835, 0.249164,
#        0.254493, 0.261605, 0.272276, 0.276728, 0.282077, 0.284757,
#        0.289217, 0.292789, 0.295473, 0.299044, 0.300833, 0.305293,
#        0.307973, 0.311549, 0.315116, 0.320462, 0.323139, 0.329376,
#        0.336501, 0.343621, 0.349859, 0.357873, 0.366773, 0.375669,
#        0.38101 , 0.388131, 0.391695, 0.398816, 0.402378, 0.41127 ,
#        0.424611, 0.434397, 0.441511, 0.45485 , 0.462854, 0.477087,
#        0.488653, 0.496659, 0.500212, 0.509101, 0.519768, 0.532217,
# ...

# %%
rdf02n1ow=np.loadtxt("/localscratch/asourpis/metadata_MOGON/rdf_high_ef/0.0/rdf_n1_ow.xvg",comments={'@','#'})
rdf02n1ow=np.loadtxt("/localscratch/asourpis/metadata_MOGON/rdf_high_ef/0.2/rdf_n1_ow.xvg",comments={'@','#'})
rdf03n1ow=np.loadtxt("/localscratch/asourpis/metadata_MOGON/rdf_high_ef/0.3/rdf_n1_ow.xvg",comments={'@','#'})
rdf04n1ow=np.loadtxt("/localscratch/asourpis/metadata_MOGON/rdf_high_ef/0.4/rdf_n1_ow.xvg",comments={'@','#'})
rdf05n1ow=np.loadtxt("/localscratch/asourpis/metadata_MOGON/rdf_high_ef/0.5/rdf_n1_ow.xvg",comments={'@','#'})
rdf06n1ow=np.loadtxt("/localscratch/asourpis/metadata_MOGON/rdf_high_ef/0.6/rdf_n1_ow.xvg",comments={'@','#'})
rdf07n1ow=np.loadtxt("/localscratch/asourpis/metadata_MOGON/rdf_high_ef/0.7/rdf_n1_ow.xvg",comments={'@','#'})
rdf08n1ow=np.loadtxt("/localscratch/asourpis/metadata_MOGON/rdf_high_ef/0.8/rdf_n1_ow.xvg",comments={'@','#'})
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-12-2a1269e79072> in <module>
# ----> 1 rdf02n1ow=np.loadtxt("/localscratch/asourpis/metadata_MOGON/rdf_high_ef/0.0/rdf_n1_ow.xvg",comments={'@','#'})
#       2 rdf02n1ow=np.loadtxt("/localscratch/asourpis/metadata_MOGON/rdf_high_ef/0.2/rdf_n1_ow.xvg",comments={'@','#'})
#       3 rdf03n1ow=np.loadtxt("/localscratch/asourpis/metadata_MOGON/rdf_high_ef/0.3/rdf_n1_ow.xvg",comments={'@','#'})
#       4 rdf04n1ow=np.loadtxt("/localscratch/asourpis/metadata_MOGON/rdf_high_ef/0.4/rdf_n1_ow.xvg",comments={'@','#'})
#       5 rdf05n1ow=np.loadtxt("/localscratch/asourpis/metadata_MOGON/rdf_high_ef/0.5/rdf_n1_ow.xvg",comments={'@','#'})
#
# ...

# %%
fig, ax = plt.subplots(1, 1, sharex='col', sharey='row')

PLOTRANGE = (0.15,0.7,0,2.0)
x = np.linspace(PLOTRANGE[0],PLOTRANGE[1],1000)

ax.get_yaxis().set_tick_params(which='both', direction='in')
ax.get_xaxis().set_tick_params(which='both', direction='in')
ax.yaxis.set_ticks_position('both')
ax.xaxis.set_ticks_position('both')
ax.xaxis.set_tick_params(labelsize=ticklabelsize)
ax.yaxis.set_tick_params(labelsize=ticklabelsize)

ax.set_xlim(PLOTRANGE[0],PLOTRANGE[1])
ax.set_ylim(PLOTRANGE[2],PLOTRANGE[3])
ax.set_aspect(1/ax.get_data_ratio())

#ax.plot(rdf01n1hw[:,0],rdf01n1hw[:,1],'-',color=tableau20[0],lw=3, label=r'$E$=0.01')
ax.plot(rdf02n1ow[:,0],rdf02n1ow[:,1],'-',color=tableau20[1],lw=3, label=r'$E$=0.2')
ax.plot(rdf03n1ow[:,0],rdf03n1ow[:,1],'-',color=tableau20[2],lw=3, label=r'$E$=0.3')
ax.plot(rdf04n1ow[:,0],rdf04n1ow[:,1],'-',color=tableau20[3],lw=3, label=r'$E$=0.4')
ax.plot(rdf05n1ow[:,0],rdf05n1ow[:,1],'-',color=tableau20[5],lw=3, label=r'$E$=0.5')
ax.plot(rdf06n1ow[:,0],rdf06n1ow[:,1],'-',color=tableau20[7],lw=3, label=r'$E$=0.6')
ax.plot(rdf07n1ow[:,0],rdf07n1ow[:,1],'-',color=tableau20[9],lw=3, label=r'$E$=0.7')
ax.plot(rdf08n1ow[:,0],rdf08n1ow[:,1],'-',color=tableau20[10],lw=3, label=r'$E$=0.8')
#ax.plot(rdf09n1hw[:,0],rdf09n1hw[:,1],'-',color=tableau20[12],lw=3, label=r'$E$=0.09')

#ax[0][0].plot(dataniki90[:,0],dataniki90[:,1],'-',color=tableau20[2],lw=3, label=r'$x_{CCN}$=0.90')
ax.legend(loc='upper right',frameon=True,shadow=False,edgecolor='black',fancybox=False,framealpha=1.0,fontsize=0.65*legendlabelsize)

#ax.text(.90, .30, r'a)', transform=ax.transAxes, ha="left", va="top",fontsize=axislabelsize)
plt.xticks(np.arange(PLOTRANGE[0]+0.1, PLOTRANGE[1]+0.1, 0.1))

ax.set_ylabel(r'g(r)', fontsize=axislabelsize) # Y label
ax.set_xlabel(r'$r_{\rm}$ [nm]', fontsize=axislabelsize) # X label

fig.suptitle('$N-O_{W}$', fontsize=16)
plt.tight_layout()
plt.savefig("rdf_n_ow_0.2-0.8.png",bbox_inches='tight',dpi=600)

# %%
rdf02n1hw=np.loadtxt("/localscratch/asourpis/metadata_MOGON/rdf_high_ef/0.2/rdf_n1_hw.xvg",comments={'@','#'})
rdf03n1hw=np.loadtxt("/localscratch/asourpis/metadata_MOGON/rdf_high_ef/0.3/rdf_n1_hw.xvg",comments={'@','#'})
rdf04n1hw=np.loadtxt("/localscratch/asourpis/metadata_MOGON/rdf_high_ef/0.4/rdf_n1_hw.xvg",comments={'@','#'})
rdf05n1hw=np.loadtxt("/localscratch/asourpis/metadata_MOGON/rdf_high_ef/0.5/rdf_n1_hw.xvg",comments={'@','#'})
rdf06n1hw=np.loadtxt("/localscratch/asourpis/metadata_MOGON/rdf_high_ef/0.6/rdf_n1_hw.xvg",comments={'@','#'})
rdf07n1hw=np.loadtxt("/localscratch/asourpis/metadata_MOGON/rdf_high_ef/0.7/rdf_n1_hw.xvg",comments={'@','#'})
rdf08n1hw=np.loadtxt("/localscratch/asourpis/metadata_MOGON/rdf_high_ef/0.8/rdf_n1_hw.xvg",comments={'@','#'})

# %%
fig, ax = plt.subplots(1, 1, sharex='col', sharey='row')

PLOTRANGE = (0.15,0.7,0,2.0)
x = np.linspace(PLOTRANGE[0],PLOTRANGE[1],1000)

ax.get_yaxis().set_tick_params(which='both', direction='in')
ax.get_xaxis().set_tick_params(which='both', direction='in')
ax.yaxis.set_ticks_position('both')
ax.xaxis.set_ticks_position('both')
ax.xaxis.set_tick_params(labelsize=ticklabelsize)
ax.yaxis.set_tick_params(labelsize=ticklabelsize)

ax.set_xlim(PLOTRANGE[0],PLOTRANGE[1])
ax.set_ylim(PLOTRANGE[2],PLOTRANGE[3])
ax.set_aspect(1/ax.get_data_ratio())

#ax.plot(rdf01n1hw[:,0],rdf01n1hw[:,1],'-',color=tableau20[0],lw=3, label=r'$E$=0.01')
ax.plot(rdf02n1hw[:,0],rdf02n1hw[:,1],'-',color=tableau20[1],lw=3, label=r'$E$=0.2')
ax.plot(rdf03n1hw[:,0],rdf03n1hw[:,1],'-',color=tableau20[2],lw=3, label=r'$E$=0.3')
ax.plot(rdf04n1hw[:,0],rdf04n1hw[:,1],'-',color=tableau20[3],lw=3, label=r'$E$=0.4')
ax.plot(rdf05n1hw[:,0],rdf05n1hw[:,1],'-',color=tableau20[5],lw=3, label=r'$E$=0.5')
ax.plot(rdf06n1hw[:,0],rdf06n1hw[:,1],'-',color=tableau20[7],lw=3, label=r'$E$=0.6')
ax.plot(rdf07n1hw[:,0],rdf07n1hw[:,1],'-',color=tableau20[9],lw=3, label=r'$E$=0.7')
ax.plot(rdf08n1hw[:,0],rdf08n1hw[:,1],'-',color=tableau20[10],lw=3, label=r'$E$=0.8')
#ax.plot(rdf09n1hw[:,0],rdf09n1hw[:,1],'-',color=tableau20[12],lw=3, label=r'$E$=0.09')

#ax[0][0].plot(dataniki90[:,0],dataniki90[:,1],'-',color=tableau20[2],lw=3, label=r'$x_{CCN}$=0.90')
ax.legend(loc='upper right',frameon=True,shadow=False,edgecolor='black',fancybox=False,framealpha=1.0,fontsize=0.65*legendlabelsize)

#ax.text(.90, .30, r'a)', transform=ax.transAxes, ha="left", va="top",fontsize=axislabelsize)
plt.xticks(np.arange(PLOTRANGE[0]+0.1, PLOTRANGE[1]+0.1, 0.1))

ax.set_ylabel(r'g(r)', fontsize=axislabelsize) # Y label
ax.set_xlabel(r'$r_{\rm}$ [nm]', fontsize=axislabelsize) # X label

fig.suptitle('$N-H_{W}$', fontsize=16)
plt.tight_layout()
plt.savefig("rdf_n_hw_0.2-0.8.png",bbox_inches='tight',dpi=600)

# %%
dataniki10=np.loadtxt("/localscratch/asourpis/metadata_MOGON/ff_evalution/niki/10/rdf_c1_c1.xvg")
dataniki50=np.loadtxt("/localscratch/asourpis/metadata_MOGON/ff_evalution/niki/50/rdf_c1_c1.xvg")
dataniki90=np.loadtxt("/localscratch/asourpis/metadata_MOGON/ff_evalution/niki/90/rdf_c1_c1.xvg")

datakows10=np.loadtxt("/localscratch/asourpis/metadata_MOGON/ff_evalution/kows/10/rdf_c1_c1.xvg")
datakows50=np.loadtxt("/localscratch/asourpis/metadata_MOGON/ff_evalution/kows/50/rdf_c1_c1.xvg")
datakows90=np.loadtxt("/localscratch/asourpis/metadata_MOGON/ff_evalution/kows/90/rdf_c1_c1.xvg")

datagrab10=np.loadtxt("/localscratch/asourpis/metadata_MOGON/ff_evalution/grab/10/rdf_c1_c1.xvg")
datagrab50=np.loadtxt("/localscratch/asourpis/metadata_MOGON/ff_evalution/grab/50/rdf_c1_c1.xvg")
datagrab90=np.loadtxt("/localscratch/asourpis/metadata_MOGON/ff_evalution/grab/90/rdf_c1_c1.xvg")

datakalu10=np.loadtxt("/localscratch/asourpis/metadata_MOGON/ff_evalution/kalu/10/rdf_c1_c1.xvg")
datakalu50=np.loadtxt("/localscratch/asourpis/metadata_MOGON/ff_evalution/kalu/50/rdf_c1_c1.xvg")
datakalu90=np.loadtxt("/localscratch/asourpis/metadata_MOGON/ff_evalution/kalu/90/rdf_c1_c1.xvg")

# %%
pwd
# Out:
# '/uni-mainz.de/homes/asourpis/Documents/gromer/PhD_roadmap/MD&electricfield/jupyternb'

# %%
rdf00owow=np.loadtxt("/localscratch/asourpis/metadata_MOGON/rdf_high_ef/0.0/rdf_ow_ow.xvg",comments={'@','#'})
rdf01owow=np.loadtxt("/localscratch/asourpis/metadata_MOGON/rdf_high_ef/0.1/rdf_ow_ow.xvg",comments={'@','#'})
rdf02owow=np.loadtxt("/localscratch/asourpis/metadata_MOGON/rdf_high_ef/0.2/rdf_ow_ow.xvg",comments={'@','#'})
rdf03owow=np.loadtxt("/localscratch/asourpis/metadata_MOGON/rdf_high_ef/0.3/rdf_ow_ow.xvg",comments={'@','#'})
rdf04owow=np.loadtxt("/localscratch/asourpis/metadata_MOGON/rdf_high_ef/0.4/rdf_ow_ow.xvg",comments={'@','#'})
rdf05owow=np.loadtxt("/localscratch/asourpis/metadata_MOGON/rdf_high_ef/0.5/rdf_ow_ow.xvg",comments={'@','#'})
rdf06owow=np.loadtxt("/localscratch/asourpis/metadata_MOGON/rdf_high_ef/0.6/rdf_ow_ow.xvg",comments={'@','#'})
rdf07owow=np.loadtxt("/localscratch/asourpis/metadata_MOGON/rdf_high_ef/0.7/rdf_ow_ow.xvg",comments={'@','#'})
rdf08owow=np.loadtxt("/localscratch/asourpis/metadata_MOGON/rdf_high_ef/0.8/rdf_ow_ow.xvg",comments={'@','#'})

# %%
fig, ax = plt.subplots(1, 1, sharex='col', sharey='row')

PLOTRANGE = (0.15,0.7,0,15.0)
x = np.linspace(PLOTRANGE[0],PLOTRANGE[1],1000)

ax.get_yaxis().set_tick_params(which='both', direction='in')
ax.get_xaxis().set_tick_params(which='both', direction='in')
ax.yaxis.set_ticks_position('both')
ax.xaxis.set_ticks_position('both')
ax.xaxis.set_tick_params(labelsize=ticklabelsize)
ax.yaxis.set_tick_params(labelsize=ticklabelsize)

ax.set_xlim(PLOTRANGE[0],PLOTRANGE[1])
ax.set_ylim(PLOTRANGE[2],PLOTRANGE[3])
ax.set_aspect(1/ax.get_data_ratio())

ax.plot(rdf00owow[:,0],rdf00owow[:,1],'-',color=tableau20[0],lw=3, label=r'$E$=0')
ax.plot(rdf01owow[:,0],rdf01owow[:,1],'-',color=tableau20[0],lw=3, label=r'$E$=0.1\;V/nm')
ax.plot(rdf02owow[:,0],rdf02owow[:,1],'-',color=tableau20[1],lw=3, label=r'$E$=0.2\;V/nm')
ax.plot(rdf03owow[:,0],rdf03owow[:,1],'-',color=tableau20[2],lw=3, label=r'$E$=0.3\;V/nm')
ax.plot(rdf04owow[:,0],rdf04owow[:,1],'-',color=tableau20[3],lw=3, label=r'$E$=0.4\;V/nm')
ax.plot(rdf05owow[:,0],rdf05owow[:,1],'-',color=tableau20[5],lw=3, label=r'$E$=0.5\;V/nm')
ax.plot(rdf06owow[:,0],rdf06owow[:,1],'-',color=tableau20[7],lw=3, label=r'$E$=0.6\;V/nm')
ax.plot(rdf07owow[:,0],rdf07owow[:,1],'-',color=tableau20[9],lw=3, label=r'$E$=0.7\;V/nm')
ax.plot(rdf08owow[:,0],rdf08owow[:,1],'-',color=tableau20[10],lw=3, label=r'$E$=0.8\;V/nm')
#ax.plot(rdf09n1hw[:,0],rdf09n1hw[:,1],'-',color=tableau20[12],lw=3, label=r'$E$=0.09')

#ax[0][0].plot(dataniki90[:,0],dataniki90[:,1],'-',color=tableau20[2],lw=3, label=r'$x_{CCN}$=0.90')
ax.legend(loc='upper right',frameon=True,shadow=False,edgecolor='black',fancybox=False,framealpha=1.0,fontsize=0.65*legendlabelsize)

#ax.text(.90, .30, r'a)', transform=ax.transAxes, ha="left", va="top",fontsize=axislabelsize)
plt.xticks(np.arange(PLOTRANGE[0]+0.1, PLOTRANGE[1]+0.1, 0.1))

ax.set_ylabel(r'g(r)', fontsize=axislabelsize) # Y label
ax.set_xlabel(r'$r_{\rm}$ [nm]', fontsize=axislabelsize) # X label

fig.suptitle('$O-O$', fontsize=16)
plt.tight_layout()
plt.savefig("rdf_o_o_0.0-0.8.png",bbox_inches='tight',dpi=600)

# %%
rdf00owhw=np.loadtxt("/localscratch/asourpis/metadata_MOGON/rdf_high_ef/0.0/rdf_ow_hw.xvg",comments={'@','#'})
rdf01owhw=np.loadtxt("/localscratch/asourpis/metadata_MOGON/rdf_high_ef/0.1/rdf_ow_hw.xvg",comments={'@','#'})
rdf02owhw=np.loadtxt("/localscratch/asourpis/metadata_MOGON/rdf_high_ef/0.2/rdf_ow_hw.xvg",comments={'@','#'})
rdf03owhw=np.loadtxt("/localscratch/asourpis/metadata_MOGON/rdf_high_ef/0.3/rdf_ow_hw.xvg",comments={'@','#'})
rdf04owhw=np.loadtxt("/localscratch/asourpis/metadata_MOGON/rdf_high_ef/0.4/rdf_ow_hw.xvg",comments={'@','#'})
rdf05owhw=np.loadtxt("/localscratch/asourpis/metadata_MOGON/rdf_high_ef/0.5/rdf_ow_hw.xvg",comments={'@','#'})
rdf06owhw=np.loadtxt("/localscratch/asourpis/metadata_MOGON/rdf_high_ef/0.6/rdf_ow_hw.xvg",comments={'@','#'})
rdf07owhw=np.loadtxt("/localscratch/asourpis/metadata_MOGON/rdf_high_ef/0.7/rdf_ow_hw.xvg",comments={'@','#'})
rdf08owhw=np.loadtxt("/localscratch/asourpis/metadata_MOGON/rdf_high_ef/0.8/rdf_ow_hw.xvg",comments={'@','#'})

# %%
fig, ax = plt.subplots(1, 1, sharex='col', sharey='row')

PLOTRANGE = (0.15,0.7,0,9.0)
x = np.linspace(PLOTRANGE[0],PLOTRANGE[1],1000)

ax.get_yaxis().set_tick_params(which='both', direction='in')
ax.get_xaxis().set_tick_params(which='both', direction='in')
ax.yaxis.set_ticks_position('both')
ax.xaxis.set_ticks_position('both')
ax.xaxis.set_tick_params(labelsize=ticklabelsize)
ax.yaxis.set_tick_params(labelsize=ticklabelsize)

ax.set_xlim(PLOTRANGE[0],PLOTRANGE[1])
ax.set_ylim(PLOTRANGE[2],PLOTRANGE[3])
ax.set_aspect(1/ax.get_data_ratio())

ax.plot(rdf00owhw[:,0],rdf00owhw[:,1],'-',color=tableau20[0],lw=3, label=r'$E$=0')
ax.plot(rdf01owhw[:,0],rdf01owhw[:,1],'-',color=tableau20[0],lw=3, label=r'$E$=0.1\;V/nm')
ax.plot(rdf02owhw[:,0],rdf02owhw[:,1],'-',color=tableau20[1],lw=3, label=r'$E$=0.2\;V/nm')
ax.plot(rdf03owhw[:,0],rdf03owhw[:,1],'-',color=tableau20[2],lw=3, label=r'$E$=0.3\;V/nm')
ax.plot(rdf04owhw[:,0],rdf04owhw[:,1],'-',color=tableau20[3],lw=3, label=r'$E$=0.4\;V/nm')
ax.plot(rdf05owhw[:,0],rdf05owhw[:,1],'-',color=tableau20[5],lw=3, label=r'$E$=0.5\;V/nm')
ax.plot(rdf06owhw[:,0],rdf06owhw[:,1],'-',color=tableau20[7],lw=3, label=r'$E$=0.6\;V/nm')
ax.plot(rdf07owhw[:,0],rdf07owhw[:,1],'-',color=tableau20[9],lw=3, label=r'$E$=0.7\;V/nm')
ax.plot(rdf08owhw[:,0],rdf08owhw[:,1],'-',color=tableau20[10],lw=3, label=r'$E$=0.8\;V/nm')
#ax.plot(rdf09n1hw[:,0],rdf09n1hw[:,1],'-',color=tableau20[12],lw=3, label=r'$E$=0.09')

#ax[0][0].plot(dataniki90[:,0],dataniki90[:,1],'-',color=tableau20[2],lw=3, label=r'$x_{CCN}$=0.90')
ax.legend(loc='upper right',frameon=True,shadow=False,edgecolor='black',fancybox=False,framealpha=1.0,fontsize=0.65*legendlabelsize)

#ax.text(.90, .30, r'a)', transform=ax.transAxes, ha="left", va="top",fontsize=axislabelsize)
plt.xticks(np.arange(PLOTRANGE[0]+0.1, PLOTRANGE[1]+0.1, 0.1))

ax.set_ylabel(r'g(r)', fontsize=axislabelsize) # Y label
ax.set_xlabel(r'$r_{\rm}$ [nm]', fontsize=axislabelsize) # X label

fig.suptitle('$O-H_{W}$', fontsize=16)
plt.tight_layout()
plt.savefig("rdf_o_hw_0-0.8.png",bbox_inches='tight',dpi=600)

# %%
rdf00c1c1=np.loadtxt("/localscratch/asourpis/metadata_MOGON/rdf_high_ef/0.0/rdf_c1_c1.xvg",comments={'@','#'})
rdf01c1c1=np.loadtxt("/localscratch/asourpis/metadata_MOGON/rdf_high_ef/0.1/rdf_c1_c1.xvg",comments={'@','#'})
rdf02c1c1=np.loadtxt("/localscratch/asourpis/metadata_MOGON/rdf_high_ef/0.2/rdf_c1_c1.xvg",comments={'@','#'})
rdf03c1c1=np.loadtxt("/localscratch/asourpis/metadata_MOGON/rdf_high_ef/0.3/rdf_c1_c1.xvg",comments={'@','#'})
rdf04c1c1=np.loadtxt("/localscratch/asourpis/metadata_MOGON/rdf_high_ef/0.4/rdf_c1_c1.xvg",comments={'@','#'})
rdf05c1c1=np.loadtxt("/localscratch/asourpis/metadata_MOGON/rdf_high_ef/0.5/rdf_c1_c1.xvg",comments={'@','#'})
rdf06c1c1=np.loadtxt("/localscratch/asourpis/metadata_MOGON/rdf_high_ef/0.6/rdf_c1_c1.xvg",comments={'@','#'})
rdf07c1c1=np.loadtxt("/localscratch/asourpis/metadata_MOGON/rdf_high_ef/0.7/rdf_c1_c1.xvg",comments={'@','#'})
rdf08c1c1=np.loadtxt("/localscratch/asourpis/metadata_MOGON/rdf_high_ef/0.8/rdf_c1_c1.xvg",comments={'@','#'})

# %%
fig, ax = plt.subplots(1, 1, sharex='col', sharey='row')

PLOTRANGE = (0.15,0.68,0,1.75)
x = np.linspace(PLOTRANGE[0],PLOTRANGE[1],1000)

ax.get_yaxis().set_tick_params(which='both', direction='in')
ax.get_xaxis().set_tick_params(which='both', direction='in')
ax.yaxis.set_ticks_position('both')
ax.xaxis.set_ticks_position('both')
ax.xaxis.set_tick_params(labelsize=ticklabelsize)
ax.yaxis.set_tick_params(labelsize=ticklabelsize)

ax.set_xlim(PLOTRANGE[0],PLOTRANGE[1])
ax.set_ylim(PLOTRANGE[2],PLOTRANGE[3])
ax.set_aspect(1/ax.get_data_ratio())

ax.plot(rdf00c1c1[:,0],rdf00c1c1[:,1],'-',color=tableau20[0],lw=3, label=r'$E$=0')
ax.plot(rdf01c1c1[:,0],rdf01c1c1[:,1],'-',color=tableau20[0],lw=3, label=r'$E$=0.1\;V/nm')
ax.plot(rdf02c1c1[:,0],rdf02c1c1[:,1],'-',color=tableau20[1],lw=3, label=r'$E$=0.2\;V/nm')
ax.plot(rdf03c1c1[:,0],rdf03c1c1[:,1],'-',color=tableau20[2],lw=3, label=r'$E$=0.3\;V/nm')
ax.plot(rdf04c1c1[:,0],rdf04c1c1[:,1],'-',color=tableau20[3],lw=3, label=r'$E$=0.4\;V/nm')
ax.plot(rdf05c1c1[:,0],rdf05c1c1[:,1],'-',color=tableau20[5],lw=3, label=r'$E$=0.5\;V/nm')
ax.plot(rdf06c1c1[:,0],rdf06c1c1[:,1],'-',color=tableau20[7],lw=3, label=r'$E$=0.6\;V/nm')
ax.plot(rdf07c1c1[:,0],rdf07c1c1[:,1],'-',color=tableau20[9],lw=3, label=r'$E$=0.7\;V/nm')
ax.plot(rdf08c1c1[:,0],rdf08c1c1[:,1],'-',color=tableau20[10],lw=3, label=r'$E$=0.8\;V/nm')
#ax.plot(rdf09n1hw[:,0],rdf09n1hw[:,1],'-',color=tableau20[12],lw=3, label=r'$E$=0.09')

#ax[0][0].plot(dataniki90[:,0],dataniki90[:,1],'-',color=tableau20[2],lw=3, label=r'$x_{CCN}$=0.90')
ax.legend(loc='upper left',frameon=True,shadow=False,edgecolor='black',fancybox=False,framealpha=1.0,fontsize=0.65*legendlabelsize)

#ax.text(.90, .30, r'a)', transform=ax.transAxes, ha="left", va="top",fontsize=axislabelsize)
plt.xticks(np.arange(PLOTRANGE[0]+0.1, PLOTRANGE[1]+0.1, 0.1))

ax.set_ylabel(r'g(r)', fontsize=axislabelsize) # Y label
ax.set_xlabel(r'$r_{\rm}$ [nm]', fontsize=axislabelsize) # X label

fig.suptitle('$C1-C1$', fontsize=16)
plt.tight_layout()
plt.savefig("rdf_c1_c1_0-0.8.png",bbox_inches='tight',dpi=600)

# %%
rdf00c2c2=np.loadtxt("/localscratch/asourpis/metadata_MOGON/rdf_high_ef/0.0/rdf_c2_c2.xvg",comments={'@','#'})
rdf01c2c2=np.loadtxt("/localscratch/asourpis/metadata_MOGON/rdf_high_ef/0.1/rdf_c2_c2.xvg",comments={'@','#'})
rdf02c2c2=np.loadtxt("/localscratch/asourpis/metadata_MOGON/rdf_high_ef/0.2/rdf_c2_c2.xvg",comments={'@','#'})
rdf03c2c2=np.loadtxt("/localscratch/asourpis/metadata_MOGON/rdf_high_ef/0.3/rdf_c2_c2.xvg",comments={'@','#'})
rdf04c2c2=np.loadtxt("/localscratch/asourpis/metadata_MOGON/rdf_high_ef/0.4/rdf_c2_c2.xvg",comments={'@','#'})
rdf05c2c2=np.loadtxt("/localscratch/asourpis/metadata_MOGON/rdf_high_ef/0.5/rdf_c2_c2.xvg",comments={'@','#'})
rdf06c2c2=np.loadtxt("/localscratch/asourpis/metadata_MOGON/rdf_high_ef/0.6/rdf_c2_c2.xvg",comments={'@','#'})
rdf07c2c2=np.loadtxt("/localscratch/asourpis/metadata_MOGON/rdf_high_ef/0.7/rdf_c2_c2.xvg",comments={'@','#'})
rdf08c2c2=np.loadtxt("/localscratch/asourpis/metadata_MOGON/rdf_high_ef/0.8/rdf_c2_c2.xvg",comments={'@','#'})

# %%
fig, ax = plt.subplots(1, 1, sharex='col', sharey='row')

PLOTRANGE = (0.15,0.7,0,2.0)
x = np.linspace(PLOTRANGE[0],PLOTRANGE[1],1000)

ax.get_yaxis().set_tick_params(which='both', direction='in')
ax.get_xaxis().set_tick_params(which='both', direction='in')
ax.yaxis.set_ticks_position('both')
ax.xaxis.set_ticks_position('both')
ax.xaxis.set_tick_params(labelsize=ticklabelsize)
ax.yaxis.set_tick_params(labelsize=ticklabelsize)

ax.set_xlim(PLOTRANGE[0],PLOTRANGE[1])
ax.set_ylim(PLOTRANGE[2],PLOTRANGE[3])
ax.set_aspect(1/ax.get_data_ratio())

ax.plot(rdf00c2c2[:,0],rdf00c2c2[:,1],'-',color=tableau20[0],lw=3, label=r'$E$=0')
ax.plot(rdf01c2c2[:,0],rdf01c2c2[:,1],'-',color=tableau20[0],lw=3, label=r'$E$=0.1\;V/nm')
ax.plot(rdf02c2c2[:,0],rdf02c2c2[:,1],'-',color=tableau20[1],lw=3, label=r'$E$=0.2\;V/nm')
ax.plot(rdf03c2c2[:,0],rdf03c2c2[:,1],'-',color=tableau20[2],lw=3, label=r'$E$=0.3\;V/nm')
ax.plot(rdf04c2c2[:,0],rdf04c2c2[:,1],'-',color=tableau20[3],lw=3, label=r'$E$=0.4\;V/nm')
ax.plot(rdf05c2c2[:,0],rdf05c2c2[:,1],'-',color=tableau20[5],lw=3, label=r'$E$=0.5\;V/nm')
ax.plot(rdf06c2c2[:,0],rdf06c2c2[:,1],'-',color=tableau20[7],lw=3, label=r'$E$=0.6\;V/nm')
ax.plot(rdf07c2c2[:,0],rdf07c2c2[:,1],'-',color=tableau20[9],lw=3, label=r'$E$=0.7\;V/nm')
ax.plot(rdf08c2c2[:,0],rdf08c2c2[:,1],'-',color=tableau20[10],lw=3, label=r'$E$=0.8\;V/nm')
#ax.plot(rdf09n1hw[:,0],rdf09n1hw[:,1],'-',color=tableau20[12],lw=3, label=r'$E$=0.09')

#ax[0][0].plot(dataniki90[:,0],dataniki90[:,1],'-',color=tableau20[2],lw=3, label=r'$x_{CCN}$=0.90')
ax.legend(loc='upper left',frameon=True,shadow=False,edgecolor='black',fancybox=False,framealpha=1.0,fontsize=0.65*legendlabelsize)

#ax.text(.90, .30, r'a)', transform=ax.transAxes, ha="left", va="top",fontsize=axislabelsize)
plt.xticks(np.arange(PLOTRANGE[0]+0.1, PLOTRANGE[1]+0.1, 0.1))

ax.set_ylabel(r'g(r)', fontsize=axislabelsize) # Y label
ax.set_xlabel(r'$r_{\rm}$ [nm]', fontsize=axislabelsize) # X label

fig.suptitle('$C2-C2$', fontsize=16)
plt.tight_layout()
plt.savefig("rdf_c2_c2_0-0.8.png",bbox_inches='tight',dpi=600)

# %%
rdf00n1hw=np.loadtxt("/localscratch/asourpis/metadata_MOGON/rdf_high_ef/0.0/rdf_n1_hw.xvg",comments={'@','#'})
rdf01n1hw=np.loadtxt("/localscratch/asourpis/metadata_MOGON/rdf_high_ef/0.1/rdf_n1_hw.xvg",comments={'@','#'})
rdf02n1hw=np.loadtxt("/localscratch/asourpis/metadata_MOGON/rdf_high_ef/0.2/rdf_n1_hw.xvg",comments={'@','#'})
rdf03n1hw=np.loadtxt("/localscratch/asourpis/metadata_MOGON/rdf_high_ef/0.3/rdf_n1_hw.xvg",comments={'@','#'})
rdf04n1hw=np.loadtxt("/localscratch/asourpis/metadata_MOGON/rdf_high_ef/0.4/rdf_n1_hw.xvg",comments={'@','#'})
rdf05n1hw=np.loadtxt("/localscratch/asourpis/metadata_MOGON/rdf_high_ef/0.5/rdf_n1_hw.xvg",comments={'@','#'})
rdf06n1hw=np.loadtxt("/localscratch/asourpis/metadata_MOGON/rdf_high_ef/0.6/rdf_n1_hw.xvg",comments={'@','#'})
rdf07n1hw=np.loadtxt("/localscratch/asourpis/metadata_MOGON/rdf_high_ef/0.7/rdf_n1_hw.xvg",comments={'@','#'})
rdf08n1hw=np.loadtxt("/localscratch/asourpis/metadata_MOGON/rdf_high_ef/0.8/rdf_n1_hw.xvg",comments={'@','#'})

# %%
fig, ax = plt.subplots(1, 1, sharex='col', sharey='row')

PLOTRANGE = (0.15,0.7,0,2.2)
x = np.linspace(PLOTRANGE[0],PLOTRANGE[1],1000)

ax.get_yaxis().set_tick_params(which='both', direction='in')
ax.get_xaxis().set_tick_params(which='both', direction='in')
ax.yaxis.set_ticks_position('both')
ax.xaxis.set_ticks_position('both')
ax.xaxis.set_tick_params(labelsize=ticklabelsize)
ax.yaxis.set_tick_params(labelsize=ticklabelsize)

ax.set_xlim(PLOTRANGE[0],PLOTRANGE[1])
ax.set_ylim(PLOTRANGE[2],PLOTRANGE[3])
ax.set_aspect(1/ax.get_data_ratio())

ax.plot(rdf00n1hw[:,0],rdf00n1hw[:,1],'-',color=tableau20[0],lw=3, label=r'$E$=0')
ax.plot(rdf01n1hw[:,0],rdf01n1hw[:,1],'-',color=tableau20[0],lw=3, label=r'$E$=0.1\;V/nm')
ax.plot(rdf02n1hw[:,0],rdf02n1hw[:,1],'-',color=tableau20[1],lw=3, label=r'$E$=0.2\;V/nm')
ax.plot(rdf03n1hw[:,0],rdf03n1hw[:,1],'-',color=tableau20[2],lw=3, label=r'$E$=0.3\;V/nm')
ax.plot(rdf04n1hw[:,0],rdf04n1hw[:,1],'-',color=tableau20[3],lw=3, label=r'$E$=0.4\;V/nm')
ax.plot(rdf05n1hw[:,0],rdf05n1hw[:,1],'-',color=tableau20[5],lw=3, label=r'$E$=0.5\;V/nm')
ax.plot(rdf06n1hw[:,0],rdf06n1hw[:,1],'-',color=tableau20[7],lw=3, label=r'$E$=0.6\;V/nm')
ax.plot(rdf07n1hw[:,0],rdf07n1hw[:,1],'-',color=tableau20[9],lw=3, label=r'$E$=0.7\;V/nm')
ax.plot(rdf08n1hw[:,0],rdf08n1hw[:,1],'-',color=tableau20[10],lw=3, label=r'$E$=0.8\;V/nm')
#ax.plot(rdf09n1hw[:,0],rdf09n1hw[:,1],'-',color=tableau20[12],lw=3, label=r'$E$=0.09')

#ax[0][0].plot(dataniki90[:,0],dataniki90[:,1],'-',color=tableau20[2],lw=3, label=r'$x_{CCN}$=0.90')
ax.legend(loc='upper right',frameon=True,shadow=False,edgecolor='black',fancybox=False,framealpha=1.0,fontsize=0.65*legendlabelsize)

#ax.text(.90, .30, r'a)', transform=ax.transAxes, ha="left", va="top",fontsize=axislabelsize)
plt.xticks(np.arange(PLOTRANGE[0]+0.1, PLOTRANGE[1]+0.1, 0.1))

ax.set_ylabel(r'g(r)', fontsize=axislabelsize) # Y label
ax.set_xlabel(r'$r_{\rm}$ [nm]', fontsize=axislabelsize) # X label

fig.suptitle('$N-H_{W}$', fontsize=16)
plt.tight_layout()
plt.savefig("rdf_n_hw_0-0.8.png",bbox_inches='tight',dpi=600)

# %%
rdf00n1h=np.loadtxt("/localscratch/asourpis/metadata_MOGON/rdf_high_ef/0.0/rdf_n1_h.xvg",comments={'@','#'})
rdf01n1h=np.loadtxt("/localscratch/asourpis/metadata_MOGON/rdf_high_ef/0.1/rdf_n1_h.xvg",comments={'@','#'})
rdf02n1h=np.loadtxt("/localscratch/asourpis/metadata_MOGON/rdf_high_ef/0.2/rdf_n1_h.xvg",comments={'@','#'})
rdf03n1h=np.loadtxt("/localscratch/asourpis/metadata_MOGON/rdf_high_ef/0.3/rdf_n1_h.xvg",comments={'@','#'})
rdf04n1h=np.loadtxt("/localscratch/asourpis/metadata_MOGON/rdf_high_ef/0.4/rdf_n1_h.xvg",comments={'@','#'})
rdf05n1h=np.loadtxt("/localscratch/asourpis/metadata_MOGON/rdf_high_ef/0.5/rdf_n1_h.xvg",comments={'@','#'})
rdf06n1h=np.loadtxt("/localscratch/asourpis/metadata_MOGON/rdf_high_ef/0.6/rdf_n1_h.xvg",comments={'@','#'})
rdf07n1h=np.loadtxt("/localscratch/asourpis/metadata_MOGON/rdf_high_ef/0.7/rdf_n1_h.xvg",comments={'@','#'})
rdf08n1h=np.loadtxt("/localscratch/asourpis/metadata_MOGON/rdf_high_ef/0.8/rdf_n1_h.xvg",comments={'@','#'})

# %%
fig, ax = plt.subplots(1, 1, sharex='col', sharey='row')

PLOTRANGE = (0.15,0.7,0,5.2)
x = np.linspace(PLOTRANGE[0],PLOTRANGE[1],1000)

ax.get_yaxis().set_tick_params(which='both', direction='in')
ax.get_xaxis().set_tick_params(which='both', direction='in')
ax.yaxis.set_ticks_position('both')
ax.xaxis.set_ticks_position('both')
ax.xaxis.set_tick_params(labelsize=ticklabelsize)
ax.yaxis.set_tick_params(labelsize=ticklabelsize)

ax.set_xlim(PLOTRANGE[0],PLOTRANGE[1])
ax.set_ylim(PLOTRANGE[2],PLOTRANGE[3])
ax.set_aspect(1/ax.get_data_ratio())

ax.plot(rdf00n1h[:,0],rdf00n1h[:,1],'-',color=tableau20[0],lw=3, label=r'$E$=0')
ax.plot(rdf01n1h[:,0],rdf01n1h[:,1],'-',color=tableau20[0],lw=3, label=r'$E$=0.1')
ax.plot(rdf02n1h[:,0],rdf02n1h[:,1],'-',color=tableau20[1],lw=3, label=r'$E$=0.2')
ax.plot(rdf03n1h[:,0],rdf03n1h[:,1],'-',color=tableau20[2],lw=3, label=r'$E$=0.3')
ax.plot(rdf04n1h[:,0],rdf04n1h[:,1],'-',color=tableau20[3],lw=3, label=r'$E$=0.4')
ax.plot(rdf05n1h[:,0],rdf05n1h[:,1],'-',color=tableau20[5],lw=3, label=r'$E$=0.5')
ax.plot(rdf06n1h[:,0],rdf06n1h[:,1],'-',color=tableau20[7],lw=3, label=r'$E$=0.6')
ax.plot(rdf07n1h[:,0],rdf07n1h[:,1],'-',color=tableau20[9],lw=3, label=r'$E$=0.7')
ax.plot(rdf08n1h[:,0],rdf08n1h[:,1],'-',color=tableau20[10],lw=3, label=r'$E$=0.8')
#ax.plot(rdf09n1h[:,0],rdf09n1h[:,1],'-',color=tableau20[12],lw=3, label=r'$E$=0.09')

#ax[0][0].plot(dataniki90[:,0],dataniki90[:,1],'-',color=tableau20[2],lw=3, label=r'$x_{CCN}$=0.90')
ax.legend(loc='upper right',frameon=True,shadow=False,edgecolor='black',fancybox=False,framealpha=1.0,fontsize=0.65*legendlabelsize)

#ax.text(.90, .30, r'a)', transform=ax.transAxes, ha="left", va="top",fontsize=axislabelsize)
plt.xticks(np.arange(PLOTRANGE[0]+0.1, PLOTRANGE[1]+0.1, 0.1))

ax.set_ylabel(r'g(r)', fontsize=axislabelsize) # Y label
ax.set_xlabel(r'$r_{\rm}$ [nm]', fontsize=axislabelsize) # X label

fig.suptitle('$N-H$', fontsize=16)
plt.tight_layout()
plt.savefig("rdf_n_hw_0.2-0.8.png",bbox_inches='tight',dpi=600)

# %%
rdf00n1n1=np.loadtxt("/localscratch/asourpis/metadata_MOGON/rdf_high_ef/0.0/rdf_n1_n1.xvg",comments={'@','#'})
rdf01n1n1=np.loadtxt("/localscratch/asourpis/metadata_MOGON/rdf_high_ef/0.1/rdf_n1_n1.xvg",comments={'@','#'})
rdf02n1n1=np.loadtxt("/localscratch/asourpis/metadata_MOGON/rdf_high_ef/0.2/rdf_n1_n1.xvg",comments={'@','#'})
rdf03n1n1=np.loadtxt("/localscratch/asourpis/metadata_MOGON/rdf_high_ef/0.3/rdf_n1_n1.xvg",comments={'@','#'})
rdf04n1n1=np.loadtxt("/localscratch/asourpis/metadata_MOGON/rdf_high_ef/0.4/rdf_n1_n1.xvg",comments={'@','#'})
rdf05n1n1=np.loadtxt("/localscratch/asourpis/metadata_MOGON/rdf_high_ef/0.5/rdf_n1_n1.xvg",comments={'@','#'})
rdf06n1n1=np.loadtxt("/localscratch/asourpis/metadata_MOGON/rdf_high_ef/0.6/rdf_n1_n1.xvg",comments={'@','#'})
rdf07n1n1=np.loadtxt("/localscratch/asourpis/metadata_MOGON/rdf_high_ef/0.7/rdf_n1_n1.xvg",comments={'@','#'})
rdf08n1n1=np.loadtxt("/localscratch/asourpis/metadata_MOGON/rdf_high_ef/0.8/rdf_n1_n1.xvg",comments={'@','#'})

# %%
fig, ax = plt.subplots(1, 1, sharex='col', sharey='row')

PLOTRANGE = (0.15,0.68,0,2.0)
x = np.linspace(PLOTRANGE[0],PLOTRANGE[1],1000)

ax.get_yaxis().set_tick_params(which='both', direction='in')
ax.get_xaxis().set_tick_params(which='both', direction='in')
ax.yaxis.set_ticks_position('both')
ax.xaxis.set_ticks_position('both')
ax.xaxis.set_tick_params(labelsize=ticklabelsize)
ax.yaxis.set_tick_params(labelsize=ticklabelsize)

ax.set_xlim(PLOTRANGE[0],PLOTRANGE[1])
ax.set_ylim(PLOTRANGE[2],PLOTRANGE[3])
ax.set_aspect(1/ax.get_data_ratio())

ax.plot(rdf00n1n1[:,0],rdf00n1n1[:,1],'-',color=tableau20[0],lw=3, label=r'$E$=0')
ax.plot(rdf01n1n1[:,0],rdf01n1n1[:,1],'-',color=tableau20[0],lw=3, label=r'$E$=0.1\;V/nm')
ax.plot(rdf02n1n1[:,0],rdf02n1n1[:,1],'-',color=tableau20[1],lw=3, label=r'$E$=0.2\;V/nm')
ax.plot(rdf03n1n1[:,0],rdf03n1n1[:,1],'-',color=tableau20[2],lw=3, label=r'$E$=0.3\;V/nm')
ax.plot(rdf04n1n1[:,0],rdf04n1n1[:,1],'-',color=tableau20[3],lw=3, label=r'$E$=0.4\;V/nm')
ax.plot(rdf05n1n1[:,0],rdf05n1n1[:,1],'-',color=tableau20[5],lw=3, label=r'$E$=0.5\;V/nm')
ax.plot(rdf06n1n1[:,0],rdf06n1n1[:,1],'-',color=tableau20[7],lw=3, label=r'$E$=0.6\;V/nm')
ax.plot(rdf07n1n1[:,0],rdf07n1n1[:,1],'-',color=tableau20[9],lw=3, label=r'$E$=0.7\;V/nm')
ax.plot(rdf08n1n1[:,0],rdf08n1n1[:,1],'-',color=tableau20[10],lw=3, label=r'$E$=0.8\;V/nm')
#ax.plot(rdf09n1n1[:,0],rdf09n1n1[:,1],'-',color=tableau20[12],lw=3, label=r'$E$=0.09')

#ax[0][0].plot(dataniki90[:,0],dataniki90[:,1],'-',color=tableau20[2],lw=3, label=r'$x_{CCN}$=0.90')
ax.legend(loc='upper left',frameon=True,shadow=False,edgecolor='black',fancybox=False,framealpha=1.0,fontsize=0.65*legendlabelsize)

#ax.text(.90, .30, r'a)', transform=ax.transAxes, ha="left", va="top",fontsize=axislabelsize)
plt.xticks(np.arange(PLOTRANGE[0]+0.1, PLOTRANGE[1]+0.1, 0.1))

ax.set_ylabel(r'g(r)', fontsize=axislabelsize) # Y label
ax.set_xlabel(r'$r_{\rm}$ [nm]', fontsize=axislabelsize) # X label

fig.suptitle('$N-N$', fontsize=16)
plt.tight_layout()
plt.savefig("rdf_n_n_0-0.8.png",bbox_inches='tight',dpi=600)

# %%
rdf00n1ow=np.loadtxt("/localscratch/asourpis/metadata_MOGON/rdf_high_ef/0.0/rdf_n1_ow.xvg",comments={'@','#'})
rdf01n1ow=np.loadtxt("/localscratch/asourpis/metadata_MOGON/rdf_high_ef/0.1/rdf_n1_ow.xvg",comments={'@','#'})
rdf02n1ow=np.loadtxt("/localscratch/asourpis/metadata_MOGON/rdf_high_ef/0.2/rdf_n1_ow.xvg",comments={'@','#'})
rdf03n1ow=np.loadtxt("/localscratch/asourpis/metadata_MOGON/rdf_high_ef/0.3/rdf_n1_ow.xvg",comments={'@','#'})
rdf04n1ow=np.loadtxt("/localscratch/asourpis/metadata_MOGON/rdf_high_ef/0.4/rdf_n1_ow.xvg",comments={'@','#'})
rdf05n1ow=np.loadtxt("/localscratch/asourpis/metadata_MOGON/rdf_high_ef/0.5/rdf_n1_ow.xvg",comments={'@','#'})
rdf06n1ow=np.loadtxt("/localscratch/asourpis/metadata_MOGON/rdf_high_ef/0.6/rdf_n1_ow.xvg",comments={'@','#'})
rdf07n1ow=np.loadtxt("/localscratch/asourpis/metadata_MOGON/rdf_high_ef/0.7/rdf_n1_ow.xvg",comments={'@','#'})
rdf08n1ow=np.loadtxt("/localscratch/asourpis/metadata_MOGON/rdf_high_ef/0.8/rdf_n1_ow.xvg",comments={'@','#'})

# %%
fig, ax = plt.subplots(1, 1, sharex='col', sharey='row')

PLOTRANGE = (0.15,0.7,0,2.3)
x = np.linspace(PLOTRANGE[0],PLOTRANGE[1],1000)

ax.get_yaxis().set_tick_params(which='both', direction='in')
ax.get_xaxis().set_tick_params(which='both', direction='in')
ax.yaxis.set_ticks_position('both')
ax.xaxis.set_ticks_position('both')
ax.xaxis.set_tick_params(labelsize=ticklabelsize)
ax.yaxis.set_tick_params(labelsize=ticklabelsize)

ax.set_xlim(PLOTRANGE[0],PLOTRANGE[1])
ax.set_ylim(PLOTRANGE[2],PLOTRANGE[3])
ax.set_aspect(1/ax.get_data_ratio())

ax.plot(rdf00n1ow[:,0],rdf00n1ow[:,1],'-',color=tableau20[0],lw=3, label=r'$E$=0')
ax.plot(rdf01n1ow[:,0],rdf01n1ow[:,1],'-',color=tableau20[0],lw=3, label=r'$E$=0.1\;V/nm')
ax.plot(rdf02n1ow[:,0],rdf02n1ow[:,1],'-',color=tableau20[1],lw=3, label=r'$E$=0.2\;V/nm')
ax.plot(rdf03n1ow[:,0],rdf03n1ow[:,1],'-',color=tableau20[2],lw=3, label=r'$E$=0.3\;V/nm')
ax.plot(rdf04n1ow[:,0],rdf04n1ow[:,1],'-',color=tableau20[3],lw=3, label=r'$E$=0.4\;V/nm')
ax.plot(rdf05n1ow[:,0],rdf05n1ow[:,1],'-',color=tableau20[5],lw=3, label=r'$E$=0.5\;V/nm')
ax.plot(rdf06n1ow[:,0],rdf06n1ow[:,1],'-',color=tableau20[7],lw=3, label=r'$E$=0.6\;V/nm')
ax.plot(rdf07n1ow[:,0],rdf07n1ow[:,1],'-',color=tableau20[9],lw=3, label=r'$E$=0.7\;V/nm')
ax.plot(rdf08n1ow[:,0],rdf08n1ow[:,1],'-',color=tableau20[10],lw=3, label=r'$E$=0.8\;V/nm')
#ax.plot(rdf09n1ow[:,0],rdf09n1ow[:,1],'-',color=tableau20[12],lw=3, label=r'$E$=0.09')

#ax[0][0].plot(dataniki90[:,0],dataniki90[:,1],'-',color=tableau20[2],lw=3, label=r'$x_{CCN}$=0.90')
ax.legend(loc='upper right',frameon=True,shadow=False,edgecolor='black',fancybox=False,framealpha=1.0,fontsize=0.65*legendlabelsize)

#ax.text(.90, .30, r'a)', transform=ax.transAxes, ha="left", va="top",fontsize=axislabelsize)
plt.xticks(np.arange(PLOTRANGE[0]+0.1, PLOTRANGE[1]+0.1, 0.1))

ax.set_ylabel(r'g(r)', fontsize=axislabelsize) # Y label
ax.set_xlabel(r'$r_{\rm}$ [nm]', fontsize=axislabelsize) # X label

fig.suptitle('$N-O$', fontsize=16)
plt.tight_layout()
plt.savefig("rdf_n_o_0-0.8.png",bbox_inches='tight',dpi=600)

# %%
rdf00ooh=np.loadtxt("/localscratch/asourpis/metadata_MOGON/rdf_high_ef/0.0/rdf_ow_h.xvg",comments={'@','#'})
rdf01ooh=np.loadtxt("/localscratch/asourpis/metadata_MOGON/rdf_high_ef/0.1/rdf_ow_h.xvg",comments={'@','#'})
rdf02ooh=np.loadtxt("/localscratch/asourpis/metadata_MOGON/rdf_high_ef/0.2/rdf_ow_h.xvg",comments={'@','#'})
rdf03ooh=np.loadtxt("/localscratch/asourpis/metadata_MOGON/rdf_high_ef/0.3/rdf_ow_h.xvg",comments={'@','#'})
rdf04ooh=np.loadtxt("/localscratch/asourpis/metadata_MOGON/rdf_high_ef/0.4/rdf_ow_h.xvg",comments={'@','#'})
rdf05ooh=np.loadtxt("/localscratch/asourpis/metadata_MOGON/rdf_high_ef/0.5/rdf_ow_h.xvg",comments={'@','#'})
rdf06ooh=np.loadtxt("/localscratch/asourpis/metadata_MOGON/rdf_high_ef/0.6/rdf_ow_h.xvg",comments={'@','#'})
rdf07ooh=np.loadtxt("/localscratch/asourpis/metadata_MOGON/rdf_high_ef/0.7/rdf_ow_h.xvg",comments={'@','#'})
rdf08ooh=np.loadtxt("/localscratch/asourpis/metadata_MOGON/rdf_high_ef/0.8/rdf_ow_h.xvg",comments={'@','#'})

# %%
fig, ax = plt.subplots(1, 1, sharex='col', sharey='row')

PLOTRANGE = (0.15,0.7,0,1.2)
x = np.linspace(PLOTRANGE[0],PLOTRANGE[1],1000)

ax.get_yaxis().set_tick_params(which='both', direction='in')
ax.get_xaxis().set_tick_params(which='both', direction='in')
ax.yaxis.set_ticks_position('both')
ax.xaxis.set_ticks_position('both')
ax.xaxis.set_tick_params(labelsize=ticklabelsize)
ax.yaxis.set_tick_params(labelsize=ticklabelsize)

ax.set_xlim(PLOTRANGE[0],PLOTRANGE[1])
ax.set_ylim(PLOTRANGE[2],PLOTRANGE[3])
ax.set_aspect(1/ax.get_data_ratio())

ax.plot(rdf00ooh[:,0],rdf00ooh[:,1],'-',color=tableau20[0],lw=3, label=r'$E$=0')
ax.plot(rdf01ooh[:,0],rdf01ooh[:,1],'-',color=tableau20[0],lw=3, label=r'$E$=0.1\;V/nm')
ax.plot(rdf02ooh[:,0],rdf02ooh[:,1],'-',color=tableau20[1],lw=3, label=r'$E$=0.2\;V/nm')
ax.plot(rdf03ooh[:,0],rdf03ooh[:,1],'-',color=tableau20[2],lw=3, label=r'$E$=0.3\;V/nm')
ax.plot(rdf04ooh[:,0],rdf04ooh[:,1],'-',color=tableau20[3],lw=3, label=r'$E$=0.4\;V/nm')
ax.plot(rdf05ooh[:,0],rdf05ooh[:,1],'-',color=tableau20[5],lw=3, label=r'$E$=0.5\;V/nm')
ax.plot(rdf06ooh[:,0],rdf06ooh[:,1],'-',color=tableau20[7],lw=3, label=r'$E$=0.6\;V/nm')
ax.plot(rdf07ooh[:,0],rdf07ooh[:,1],'-',color=tableau20[9],lw=3, label=r'$E$=0.7\;V/nm')
ax.plot(rdf08ooh[:,0],rdf08ooh[:,1],'-',color=tableau20[10],lw=3, label=r'$E$=0.8\;V/nm')
#ax.plot(rdf09ooh[:,0],rdf09ooh[:,1],'-',color=tableau20[12],lw=3, label=r'$E$=0.09')

#ax[0][0].plot(dataniki90[:,0],dataniki90[:,1],'-',color=tableau20[2],lw=3, label=r'$x_{CCN}$=0.90')
ax.legend(loc='lower right',frameon=True,shadow=False,edgecolor='black',fancybox=False,framealpha=1.0,fontsize=0.65*legendlabelsize)

#ax.text(.90, .30, r'a)', transform=ax.transAxes, ha="left", va="top",fontsize=axislabelsize)
plt.xticks(np.arange(PLOTRANGE[0]+0.1, PLOTRANGE[1]+0.1, 0.1))

ax.set_ylabel(r'g(r)', fontsize=axislabelsize) # Y label
ax.set_xlabel(r'$r_{\rm}$ [nm]', fontsize=axislabelsize) # X label

fig.suptitle('$O-H$', fontsize=16)
plt.tight_layout()
plt.savefig("rdf_o_h_0-0.8.png",bbox_inches='tight',dpi=600)

# %%
pwd
# Out:
# '/uni-mainz.de/homes/asourpis/Documents/gromer/PhD_roadmap/MD&electricfield/jupyternb'

# %%
/uni-mainz.de/homes/asourpis/Documents/gromer/PhD_roadmap/MD\&electricfield/jupyternb
